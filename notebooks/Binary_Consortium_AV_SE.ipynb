# %% [markdown]
# # Running the Micom Workflow for the Binary Azotobacter - Synechococcus Model

# %% [markdown]
# In this notebook we utilize the package `micom` to generate a binary community model for 2 organisms of interest:
# - `Azotobacter vinelandii`
# - `Synechococcus elongatus`
#
# This binary consortium allows us to gain insights into the exchanges between the 2 organisms and run FBA experiments.
#
# First off we can import all necessary packages for this notebook.

# %%
import pandas as pd
import cobra

from micom import Community
from micom.workflows import build, grow, tradeoff, fix_medium,build_database
from micom import load_pickle
from micom.viz import plot_tradeoff, plot_exchanges_per_sample, plot_growth

import os
os.environ["GRB_LICENSE_FILE"]
# Out:
# '/Users/mcna892/Desktop/Projects/Digital_Twins/gurobi.lic'

# %% [markdown]
# ## Setting Up the Model in MICOM

# %% [markdown]
# To begin, we need to import our genome-scale models into `micom`. We have these models saved as `.sbml` files as this form is accepted easily into programs such as `cobrapy` and `micom`.

# %% [markdown]
# ### Building a Taxonomy
#
# Step #1: Establish a Taxonomy that lists the out the taxonomy for our organisms of interest

# %%
Tax= pd.DataFrame(columns=['id','genus','species','reactions','metabolites','sample_id','abundance'])
Tax.loc[len(Tax.index)] = ['Synechococcus', 'Synechococcus','S. elongatus',851,769,'One',500]
Tax.loc[len(Tax.index)] = ['Azotobacter','Azotobacter','A. vinelandii',2469,2003,'One',500]
Tax
# Out:
#               id          genus        species  reactions  metabolites  \
# 0  Synechococcus  Synechococcus   S. elongatus        851          769
# 1    Azotobacter    Azotobacter  A. vinelandii       2469         2003
#
#   sample_id  abundance
# 0       One        500
# 1       One        500

# %% [markdown]
# This taxonomy file lists important information for `micom` down the road, such as the number of `reactions` and `metabolites` in the provided models.

# %% [markdown]
# ### Building a Database
#
# Step #2: Now we must construct a database for the `.sbml` models to be preprocessed and stored. This is done by supplying `micom` with a file which contains model path locations.

# %%
db = pd.read_csv('./man_av_se.csv')
db
# Out:
#              file   kingdom          phylum                class  \
# 0    ./iJB785.xml  bacteria   Cyanobacteria         Cyanophyceae
# 1  ./azo_vine.xml  bacteria  Pseudomonadota  Gammaproteobacteria
#
#              order            family          genus        species
# 0  Synechococcales  Synechococcaceae  Synechococcus   S. elongatus
# 1  Pseudomonadales  Pseudomonadaceae    Azotobacter  A. vinelandii

# %%
build_database(db,'./db_av_se')
# Out:
# /Users/mcna892/opt/anaconda3/envs/micom/lib/python3.9/site-packages/rich/live.py:231: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# [15:02:56] WARNING  The following sinks or demands were forced in the model and have been relaxed since  ]8;id=398020;file:///Users/mcna892/opt/anaconda3/envs/micom/lib/python3.9/site-packages/micom/util.py\util.py]8;;\:]8;id=460386;file:///Users/mcna892/opt/anaconda3/envs/micom/lib/python3.9/site-packages/micom/util.py#64\64]8;;\
#                     they would interfere with MICOM's growth rate estimation: EX_sucr_e
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                              file   kingdom          phylum  \
# genus
# Azotobacter      Azotobacter.json  bacteria  Pseudomonadota
# Synechococcus  Synechococcus.json  bacteria   Cyanobacteria
#
#                              class            order            family  \
# genus
# Azotobacter    Gammaproteobacteria  Pseudomonadales  Pseudomonadaceae
# Synechococcus         Cyanophyceae  Synechococcales  Synechococcaceae
#
#                        genus        species             id summary_rank
# genus
# Azotobacter      Azotobacter  A. vinelandii    Azotobacter        genus
# Synechococcus  Synechococcus   S. elongatus  Synechococcus        genus

# %%
db_path = './db_av_se'

# %% [markdown]
# ### Construct Manifest Object
#
# Step #3: Now that we have the Taxonomy and Database constructed we can build our community model. This is done by using the `build()` method in `micom`.
#
# __Note__:
#
# Build Manifest object from Taxonomy DataFrame and the corresponding database directory
#
# Skip this step if manifest has already been built and saved to "models" directory
#
#
# __IMPORTANT__: Declare the Solver you would like to use for this Community model here:
# - osqp (good for smaller models)
# - gurobi
# - glpk
# - cplex
# - scipy

# %%
manifest = build(Tax, out_folder="models_av_se", model_db=db_path, cutoff=0.0001, threads=10,solver='gurobi')
manifest
# Out:
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#   sample_id  abundance        file  found_taxa  total_taxa  found_fraction  \
# 0       One        500  One.pickle         2.0         2.0             1.0
#
#    found_abundance_fraction
# 0                       1.0

# %% [markdown]
# ## Running the Models with FBA
#
# Now that we have the `manifest`, we can load the model as a `Community` object through `micom`. This will give us some functionality similar to that of `cobrapy`. This can be done with the `load_pickle()` method we imported above through `micom`.

# %%
community = load_pickle("models_av_se/One.pickle")
print(len(community.reactions))
# Out:
# Read LP format model from file /var/folders/1f/ksln774x1hd1pzfgsjgpxt7r0000gn/T/tmp_jxqj2f_.lp
# Reading time = 0.03 seconds
# : 3116 rows, 7325 columns, 28585 nonzeros
# 3662

# %% [markdown]
# ### Exploring the Model Attributes

# %% [markdown]
# Our new variable `community` behaves very similarly to a standard `cobrapy` model. We can explore it's attributes in a similar way as well.
#
# Things such as `reactions` and `metabolites`:

# %%
community.reactions
# Out:
# [<Reaction EX_gln__L_e__Synechococcus at 0x34fe313a0>,
#  <Reaction EX_hco3_e__Synechococcus at 0x34fe314c0>,
#  <Reaction EX_mn2_e__Synechococcus at 0x34fe315b0>,
#  <Reaction EX_arg__L_e__Synechococcus at 0x34fe316a0>,
#  <Reaction ADPT__Synechococcus at 0x34fe31790>,
#  <Reaction O2tcx__Synechococcus at 0x34fe31940>,
#  <Reaction AOXPBDC__Synechococcus at 0x34fe31a00>,
#  <Reaction DNTPPA__Synechococcus at 0x34fe31c10>,
#  <Reaction CBMD__Synechococcus at 0x34fe31dc0>,
#  <Reaction BIOMASS_PIGMENTS__Synechococcus at 0x34fe3e160>,
#  <Reaction H2Otu_syn__Synechococcus at 0x34fe443d0>,
#  <Reaction DTMPK__Synechococcus at 0x34fe61d90>,
#  <Reaction BIOMASS__1__Synechococcus at 0x34fe78ee0>,
#  <Reaction ORNTA__Synechococcus at 0x34fe88340>,
#  <Reaction ATPM__Synechococcus at 0x34fe88610>,
#  <Reaction ACOATA__Synechococcus at 0x34fe88460>,
#  <Reaction 5DOAN__Synechococcus at 0x34fe88b50>,
#  <Reaction 3HAD160__Synechococcus at 0x34feca310>,
#  <Reaction RNDR3__Synechococcus at 0x34fecaca0>,
#  <Reaction Htex__Synechococcus at 0x34fed2af0>,
#  <Reaction G5SD__Synechococcus at 0x34ff09820>,
#  <Reaction HISTDa__Synechococcus at 0x34ff11fa0>,
#  <Reaction TRPS3__Synechococcus at 0x34ff69040>,
#  <Reaction DMBZIDS2__Synechococcus at 0x3504f91c0>,
#  <Reaction HSTPT__Synechococcus at 0x35051cd30>,
#  <Reaction ZCAROTDH2__Synechococcus at 0x350543cd0>,
#  <Reaction ORNDC__Synechococcus at 0x3508b7be0>,
#  <Reaction GND__Synechococcus at 0x34ff82a00>,
#  <Reaction CMPA_1__Synechococcus at 0x350b67040>,
#  <Reaction U23GAAT2__Synechococcus at 0x350c55070>,
#  <Reaction HOXGfx__Synechococcus at 0x350f8f1f0>,
#  <Reaction PGK__Synechococcus at 0x350fb3670>,
#  <Reaction IMPD__Synechococcus at 0x350fd67c0>,
#  <Reaction LPOR__Synechococcus at 0x350ffe580>,
#  <Reaction CHRPL__Synechococcus at 0x35101ed60>,
#  <Reaction GCALDDy__Synechococcus at 0x35102f4c0>,
#  <Reaction MSBENZMT__Synechococcus at 0x35107c400>,
#  <Reaction DESAT18a__Synechococcus at 0x3510bb550>,
#  <Reaction FUM__Synechococcus at 0x3510da280>,
#  <Reaction PHYFXOR__Synechococcus at 0x35110ff10>,
#  <Reaction TMPPP_1__Synechococcus at 0x35114aee0>,
#  <Reaction VPAMTr__Synechococcus at 0x3511570d0>,
#  <Reaction RNDR1__Synechococcus at 0x351193520>,
#  <Reaction TALA__Synechococcus at 0x3511bfee0>,
#  <Reaction GLYCL__Synechococcus at 0x351206fd0>,
#  <Reaction ACONT__Synechococcus at 0x3512abf70>,
#  <Reaction NDPK7__Synechococcus at 0x3511524c0>,
#  <Reaction GTPCI__Synechococcus at 0x3512ba130>,
#  <Reaction AIRC2__Synechococcus at 0x351321a30>,
#  <Reaction IGPS__Synechococcus at 0x35127acd0>,
#  <Reaction MTAP__Synechococcus at 0x3517cd280>,
#  <Reaction HEMEAS_1__Synechococcus at 0x3517fb1c0>,
#  <Reaction DHORD3um__Synechococcus at 0x351800280>,
#  <Reaction MTHFC__Synechococcus at 0x351850820>,
#  <Reaction HBZNPT__Synechococcus at 0x351873bb0>,
#  <Reaction GCATENEC__Synechococcus at 0x3518a72e0>,
#  <Reaction COCHL_1__Synechococcus at 0x3518b8130>,
#  <Reaction HSDy__Synechococcus at 0x3518cd160>,
#  <Reaction TRPS1__Synechococcus at 0x3518f1610>,
#  <Reaction HISTDb__Synechococcus at 0x351978ac0>,
#  <Reaction UPPDC1__Synechococcus at 0x35184af10>,
#  <Reaction GARFT__Synechococcus at 0x351d24190>,
#  <Reaction H4THDPR__Synechococcus at 0x351e58490>,
#  <Reaction UDPG4E__Synechococcus at 0x3521bd160>,
#  <Reaction GLCS3__Synechococcus at 0x352139190>,
#  <Reaction AICART__Synechococcus at 0x3521c70d0>,
#  <Reaction ASPTA__Synechococcus at 0x352214700>,
#  <Reaction GLYOX__Synechococcus at 0x352255850>,
#  <Reaction PRAGSr__Synechococcus at 0x352244be0>,
#  <Reaction SQD1__Synechococcus at 0x352287d90>,
#  <Reaction ACKr__Synechococcus at 0x352296430>,
#  <Reaction UDCPDPS__Synechococcus at 0x3526953d0>,
#  <Reaction GK1__Synechococcus at 0x3527179d0>,
#  <Reaction SHKK__Synechococcus at 0x352731a30>,
#  <Reaction OXADC__Synechococcus at 0x352776160>,
#  <Reaction G1PACT__Synechococcus at 0x3527a9100>,
#  <Reaction 3HAD60__Synechococcus at 0x352784c10>,
#  <Reaction PGI__Synechococcus at 0x3527b3940>,
#  <Reaction KAS14__Synechococcus at 0x352817e20>,
#  <Reaction OHPBAT__Synechococcus at 0x3528009a0>,
#  <Reaction PQH2tum__Synechococcus at 0x35282f6d0>,
#  <Reaction O2tu__Synechococcus at 0x3527fc1f0>,
#  <Reaction O2tpp__Synechococcus at 0x352898160>,
#  <Reaction H2Otex__Synechococcus at 0x3528d2340>,
#  <Reaction SK_for_c__Synechococcus at 0x3528d2670>,
#  <Reaction EX_mg2_e__Synechococcus at 0x3528d9280>,
#  <Reaction 3HAD80__Synechococcus at 0x35290d2b0>,
#  <Reaction 3OAR160__Synechococcus at 0x35290da90>,
#  <Reaction NMNS__Synechococcus at 0x352928490>,
#  <Reaction PPK__Synechococcus at 0x352940eb0>,
#  <Reaction GALUi__Synechococcus at 0x35296d850>,
#  <Reaction PHYTES2_1__Synechococcus at 0x35298d490>,
#  <Reaction IGPDH__Synechococcus at 0x3529c73a0>,
#  <Reaction OMPDC__Synechococcus at 0x352a2bb50>,
#  <Reaction DCTPD__Synechococcus at 0x352a016a0>,
#  <Reaction GLUSfx__Synechococcus at 0x352a70e50>,
#  <Reaction NADS2__Synechococcus at 0x352a7e2e0>,
#  <Reaction GLUTRR__Synechococcus at 0x352adc8e0>,
#  <Reaction G1PTT__Synechococcus at 0x352b1e280>,
#  <Reaction UAMAGS__Synechococcus at 0x352b5b190>,
#  <Reaction SPS__Synechococcus at 0x352b9efa0>,
#  <Reaction ADCL__Synechococcus at 0x352bd0ca0>,
#  <Reaction CYTK1__Synechococcus at 0x352c0aaf0>,
#  <Reaction DAPDC__Synechococcus at 0x352c53130>,
#  <Reaction PSIum__Synechococcus at 0x352c46e20>,
#  <Reaction R05219__Synechococcus at 0x352d29100>,
#  <Reaction Cobalt2abcppI__Synechococcus at 0x352cbd8e0>,
#  <Reaction PFK_3__Synechococcus at 0x352cf6100>,
#  <Reaction THRS__Synechococcus at 0x352d41a90>,
#  <Reaction NAMNPP__Synechococcus at 0x352d39dc0>,
#  <Reaction FOLD3__Synechococcus at 0x3532c60a0>,
#  <Reaction P5CR__Synechococcus at 0x35362e610>,
#  <Reaction MEHLER_1__Synechococcus at 0x35364da30>,
#  <Reaction ICHORS__Synechococcus at 0x3539b4f70>,
#  <Reaction 3OAS140__Synechococcus at 0x353677160>,
#  <Reaction PPK2__Synechococcus at 0x3539ff6d0>,
#  <Reaction IPDPS_syn__Synechococcus at 0x353a61280>,
#  <Reaction GLYDHDA__Synechococcus at 0x3539e1040>,
#  <Reaction SBP__Synechococcus at 0x353ddc1c0>,
#  <Reaction H4THDPS__Synechococcus at 0x353daa580>,
#  <Reaction EAR60y__Synechococcus at 0x353e1f7c0>,
#  <Reaction ZNabcpp__Synechococcus at 0x353e6ceb0>,
#  <Reaction UAPGR__Synechococcus at 0x353ec9100>,
#  <Reaction DHAD1__Synechococcus at 0x353e9c4c0>,
#  <Reaction IPPS__Synechococcus at 0x353eef2b0>,
#  <Reaction ANS__Synechococcus at 0x353f04040>,
#  <Reaction SUCBZL__Synechococcus at 0x35434e220>,
#  <Reaction ADSL1r__Synechococcus at 0x354382c70>,
#  <Reaction NNATr__Synechococcus at 0x354363550>,
#  <Reaction PERD__Synechococcus at 0x3543dea90>,
#  <Reaction PPBNGS__Synechococcus at 0x35466c970>,
#  <Reaction ADOCBLS__Synechococcus at 0x35475e910>,
#  <Reaction LTHRK__Synechococcus at 0x3547afcd0>,
#  <Reaction PPS__Synechococcus at 0x354b5e160>,
#  <Reaction APRAUR__Synechococcus at 0x354b54dc0>,
#  <Reaction PDS2_1__Synechococcus at 0x3547d2190>,
#  <Reaction O2tex__Synechococcus at 0x354ba7a00>,
#  <Reaction ALAALAr__Synechococcus at 0x354b7de20>,
#  <Reaction ADCPS2__Synechococcus at 0x354f57610>,
#  <Reaction GF6PTA__Synechococcus at 0x354ef17c0>,
#  <Reaction DNMPPA__Synechococcus at 0x354f71700>,
#  <Reaction PGMT__Synechococcus at 0x354f57d60>,
#  <Reaction G5SADs__Synechococcus at 0x354f779d0>,
#  <Reaction GLCP2_1__Synechococcus at 0x354f9b5b0>,
#  <Reaction AGDI_1__Synechococcus at 0x354fc85e0>,
#  <Reaction LPADSS2__Synechococcus at 0x354fed4c0>,
#  <Reaction GLYCK__Synechococcus at 0x354ff2850>,
#  <Reaction DPR__Synechococcus at 0x35503afd0>,
#  <Reaction EX_ptrc_e__Synechococcus at 0x355068160>,
#  <Reaction EAR120y__Synechococcus at 0x355093dc0>,
#  <Reaction MAN1PT__Synechococcus at 0x3550a3250>,
#  <Reaction NMNAT__Synechococcus at 0x3550d81f0>,
#  <Reaction TKT2__Synechococcus at 0x355114130>,
#  <Reaction PSP_L__Synechococcus at 0x3550d8340>,
#  <Reaction HEX7__Synechococcus at 0x3551520d0>,
#  <Reaction PPNCL2__Synechococcus at 0x3551bbbe0>,
#  <Reaction CHORS__Synechococcus at 0x35562a7f0>,
#  <Reaction CYTBD4cm__Synechococcus at 0x35563b400>,
#  <Reaction PPNCL3__Synechococcus at 0x35565bc10>,
#  <Reaction CS__Synechococcus at 0x35562a400>,
#  <Reaction PPCDC__Synechococcus at 0x35568e3a0>,
#  <Reaction LDH_D__Synechococcus at 0x3556b74c0>,
#  <Reaction HPYRRy__Synechococcus at 0x355665400>,
#  <Reaction ADMDC__Synechococcus at 0x355acc850>,
#  <Reaction PRE3BS__Synechococcus at 0x35566a460>,
#  <Reaction PPPGO2_1__Synechococcus at 0x3556e0370>,
#  <Reaction BIOMASS_DNA__Synechococcus at 0x355b5d400>,
#  <Reaction DMATT__Synechococcus at 0x355f4c0a0>,
#  <Reaction DNAMTn2r__Synechococcus at 0x355b34d30>,
#  <Reaction G3PD2__Synechococcus at 0x355ea7bb0>,
#  <Reaction BIOMASS_CELL_WALL__Synechococcus at 0x355fe15e0>,
#  <Reaction PHYTES__Synechococcus at 0x35635aa00>,
#  <Reaction RB15BPtcx__Synechococcus at 0x356315160>,
#  <Reaction MI3PP__Synechococcus at 0x356384940>,
#  <Reaction MOHMT__Synechococcus at 0x35638f5b0>,
#  <Reaction GLXO3r__Synechococcus at 0x3563695b0>,
#  <Reaction FBA__Synechococcus at 0x35638f220>,
#  <Reaction RZ5PP__Synechococcus at 0x3563b7370>,
#  <Reaction PROAKGOX1__Synechococcus at 0x3563b2f40>,
#  <Reaction ASAD__Synechococcus at 0x356405ee0>,
#  <Reaction CYSS_2__Synechococcus at 0x35640f400>,
#  <Reaction LYCOPC__Synechococcus at 0x356458f40>,
#  <Reaction ACOTA__Synechococcus at 0x35642ef10>,
#  <Reaction 3HAD180__Synechococcus at 0x3563e3100>,
#  <Reaction FTHFD__Synechococcus at 0x356888430>,
#  <Reaction ALDD2y__Synechococcus at 0x356915d00>,
#  <Reaction 3OAS80__Synechococcus at 0x35690c5e0>,
#  <Reaction PSCVT__Synechococcus at 0x356923580>,
#  <Reaction CBPS__Synechococcus at 0x3569486d0>,
#  <Reaction NTPP8__Synechococcus at 0x356458ee0>,
#  <Reaction MEPCT__Synechococcus at 0x3564c8ee0>,
#  <Reaction PDX5POi__Synechococcus at 0x3569bee80>,
#  <Reaction DHAD2__Synechococcus at 0x356a2ce20>,
#  <Reaction DHFS__Synechococcus at 0x356e43d90>,
#  <Reaction PGCD__Synechococcus at 0x356e6dcd0>,
#  <Reaction SPMDabcpp__Synechococcus at 0x356e52430>,
#  <Reaction NTD6__Synechococcus at 0x356e77700>,
#  <Reaction NNDMBRT__Synechococcus at 0x356ec0b50>,
#  <Reaction PRATPP__Synechococcus at 0x356eee1c0>,
#  <Reaction ASNN__Synechococcus at 0x356ef70d0>,
#  <Reaction SERAT__Synechococcus at 0x356f21520>,
#  <Reaction PRAIS__Synechococcus at 0x356ef24c0>,
#  <Reaction PRAMPC__Synechococcus at 0x356ec42b0>,
#  <Reaction AMPMS3__Synechococcus at 0x356fe0610>,
#  <Reaction G1PCTYT__Synechococcus at 0x35701a520>,
#  <Reaction ACBIPGT__Synechococcus at 0x356f5b220>,
#  <Reaction SEPHCHCS__Synechococcus at 0x357391460>,
#  <Reaction NMNDA__Synechococcus at 0x356f1c8e0>,
#  <Reaction CA2abcpp__Synechococcus at 0x357023a30>,
#  <Reaction ORNTAC__Synechococcus at 0x357603d00>,
#  <Reaction SUCBZS__Synechococcus at 0x35760c220>,
#  <Reaction UHGADA2__Synechococcus at 0x357635130>,
#  <Reaction DHNANT__Synechococcus at 0x357659070>,
#  <Reaction ASPO6__Synechococcus at 0x35767efd0>,
#  <Reaction HGYDAS__Synechococcus at 0x3576a64c0>,
#  <Reaction GGDPR__Synechococcus at 0x357722040>,
#  <Reaction ASP1DC__Synechococcus at 0x357764dc0>,
#  <Reaction PPNDH__Synechococcus at 0x357baea90>,
#  <Reaction ASPK__Synechococcus at 0x357bccf70>,
#  <Reaction DXPS__Synechococcus at 0x357bd3310>,
#  <Reaction ME2__Synechococcus at 0x357bfbf70>,
#  <Reaction 3PGtcx__Synechococcus at 0x357c24eb0>,
#  <Reaction DDPGA__Synechococcus at 0x3576e9160>,
#  <Reaction PAPSR__Synechococcus at 0x357c7a040>,
#  <Reaction SADT__Synechococcus at 0x357c9aa00>,
#  <Reaction BIOMASS_COFACTORS__Synechococcus at 0x357cc4730>,
#  <Reaction DPCOAK__Synechococcus at 0x357d2ea30>,
#  <Reaction NH4tpp__Synechococcus at 0x357d35100>,
#  <Reaction DM_h2_c__Synechococcus at 0x357d600d0>,
#  <Reaction PC11M__Synechococcus at 0x357d359d0>,
#  <Reaction DPOR__Synechococcus at 0x357d78a60>,
#  <Reaction ARGSL__Synechococcus at 0x358212ac0>,
#  <Reaction HSK__Synechococcus at 0x357da4490>,
#  <Reaction MTHFD__Synechococcus at 0x357ddc040>,
#  <Reaction PMDPHT__Synechococcus at 0x3582648b0>,
#  <Reaction ARGabcpp__Synechococcus at 0x357de39d0>,
#  <Reaction 3HAD140__Synechococcus at 0x35861a8b0>,
#  <Reaction ARGOXRum__Synechococcus at 0x358244e20>,
#  <Reaction DAPE__Synechococcus at 0x35862ca90>,
#  <Reaction BCAROHX2__Synechococcus at 0x358680370>,
#  <Reaction HPPK__Synechococcus at 0x35862c460>,
#  <Reaction PANTS__Synechococcus at 0x358a36820>,
#  <Reaction AHCi__Synechococcus at 0x358a5fb80>,
#  <Reaction G6PDH2r__Synechococcus at 0x358a82eb0>,
#  <Reaction ALAD_L__Synechococcus at 0x358afa250>,
#  <Reaction GTPCII__Synechococcus at 0x358a36550>,
#  <Reaction GLCBRAN3__Synechococcus at 0x3585de940>,
#  <Reaction DB4PS__Synechococcus at 0x358ab19a0>,
#  <Reaction DXPRIi__Synechococcus at 0x358afe9a0>,
#  <Reaction FBA3__Synechococcus at 0x358b82370>,
#  <Reaction RBFSa__Synechococcus at 0x358b27e20>,
#  <Reaction GLUTRS__Synechococcus at 0x35902aaf0>,
#  <Reaction MPOMMM__Synechococcus at 0x359039ca0>,
#  <Reaction METAT__Synechococcus at 0x35907e4c0>,
#  <Reaction EAR160y__Synechococcus at 0x3590839a0>,
#  <Reaction DHORTS__Synechococcus at 0x3590a6970>,
#  <Reaction PDX5PS2__Synechococcus at 0x3590d5640>,
#  <Reaction KARI_23dhmp_1__Synechococcus at 0x3590f9790>,
#  <Reaction ARGDC__Synechococcus at 0x358b50a30>,
#  <Reaction GAPDi_nadp__Synechococcus at 0x3590cf6a0>,
#  <Reaction NTD7__Synechococcus at 0x3591acd90>,
#  <Reaction AIRC3__Synechococcus at 0x359054d60>,
#  <Reaction UMPK__Synechococcus at 0x3591f5070>,
#  <Reaction ASPOb__Synechococcus at 0x359229640>,
#  <Reaction RBFSb_1__Synechococcus at 0x35914ba60>,
#  <Reaction SUCDum__Synechococcus at 0x359295ee0>,
#  <Reaction FBP__Synechococcus at 0x35932c190>,
#  <Reaction CITCIb__Synechococcus at 0x3592d0af0>,
#  <Reaction MNabc_1__Synechococcus at 0x35934c970>,
#  <Reaction TMPK__Synechococcus at 0x359bc7d60>,
#  <Reaction AGPR__Synechococcus at 0x359b4a130>,
#  <Reaction IPMD__Synechococcus at 0x3597b7550>,
#  <Reaction CDPMEK__Synechococcus at 0x359851d60>,
#  <Reaction DVOCHR_1__Synechococcus at 0x359ee46d0>,
#  <Reaction H2CO3_NAt_syn__Synechococcus at 0x35a23b460>,
#  <Reaction HEMEOS__Synechococcus at 0x35a25c760>,
#  <Reaction PMANM__Synechococcus at 0x35a216670>,
#  <Reaction RPE__Synechococcus at 0x35a2625b0>,
#  <Reaction MPOMT_1__Synechococcus at 0x35a285070>,
#  <Reaction CPPPGO2__Synechococcus at 0x35a325d60>,
#  <Reaction PC17M_1__Synechococcus at 0x35a330280>,
#  <Reaction UAMAS__Synechococcus at 0x35a356430>,
#  <Reaction GLUCYS__Synechococcus at 0x35a38c250>,
#  <Reaction NDHPQRum__Synechococcus at 0x35a3b9e80>,
#  <Reaction CYNL__Synechococcus at 0x35a3fd430>,
#  <Reaction DCTPD2__Synechococcus at 0x35a3b9d30>,
#  <Reaction CYOOum__Synechococcus at 0x35a468880>,
#  <Reaction BPNT2__Synechococcus at 0x35a90c9a0>,
#  <Reaction METS_1__Synechococcus at 0x35a301640>,
#  <Reaction PRUK__Synechococcus at 0x35a4d40d0>,
#  <Reaction FNOR_1__Synechococcus at 0x35a42efd0>,
#  <Reaction GART__Synechococcus at 0x35a4dc5e0>,
#  <Reaction IPPMIb__Synechococcus at 0x35a2af5b0>,
#  <Reaction DMTPHT__Synechococcus at 0x35a959ca0>,
#  <Reaction PC6YM_1__Synechococcus at 0x35a8f40a0>,
#  <Reaction PGL__Synechococcus at 0x35b089b80>,
#  <Reaction DDPA__Synechococcus at 0x35b107070>,
#  <Reaction ASPCT__Synechococcus at 0x35b4b1b50>,
#  <Reaction HSERTA__Synechococcus at 0x35b4702e0>,
#  <Reaction OMCDC__Synechococcus at 0x35b4e05e0>,
#  <Reaction CYRDAAT__Synechococcus at 0x35b0ad8b0>,
#  <Reaction MECDPDHf__Synechococcus at 0x35b936370>,
#  <Reaction Htcx__Synechococcus at 0x35b52dac0>,
#  <Reaction H2Otpp__Synechococcus at 0x35b5844f0>,
#  <Reaction HISTP__Synechococcus at 0x35bbf3400>,
#  <Reaction MTHFR3_1__Synechococcus at 0x35bc62a00>,
#  <Reaction EX_ca2_e__Synechococcus at 0x35c0811f0>,
#  <Reaction 3HAD40_2__Synechococcus at 0x35c0a3f10>,
#  <Reaction ZCAROTDH1__Synechococcus at 0x35c00fa00>,
#  <Reaction CYRDAR__Synechococcus at 0x35c0bf400>,
#  <Reaction BIOMASS_MEM_LIPIDS__Synechococcus at 0x35c00f700>,
#  <Reaction HCO3tcx__Synechococcus at 0x35c0fbaf0>,
#  <Reaction GLYALDDy__Synechococcus at 0x35c120220>,
#  <Reaction IMPC__Synechococcus at 0x35c13a3d0>,
#  <Reaction BIOMASS_PROTEIN__Synechococcus at 0x35c1241c0>,
#  <Reaction LDAPAT__Synechococcus at 0x35c19cfd0>,
#  <Reaction EX_nh4_e__Synechococcus at 0x35c19c2e0>,
#  <Reaction 3OAR40_2__Synechococcus at 0x35c1a0310>,
#  <Reaction RNDR2__Synechococcus at 0x35c1a0400>,
#  <Reaction GRTT__Synechococcus at 0x35c1a05e0>,
#  <Reaction NPDPS__Synechococcus at 0x35c1a02e0>,
#  <Reaction 3OAS100__Synechococcus at 0x35c1a7280>,
#  <Reaction ADSL2r__Synechococcus at 0x35c1e0af0>,
#  <Reaction MAN6PI__Synechococcus at 0x35c21aa30>,
#  <Reaction HPROb__Synechococcus at 0x35c256730>,
#  <Reaction 3OAS120__Synechococcus at 0x35c1d7ac0>,
#  <Reaction NTPP2__Synechococcus at 0x35c2c16d0>,
#  <Reaction EAR180y__Synechococcus at 0x35c3300d0>,
#  <Reaction DHQTi__Synechococcus at 0x35c1a0430>,
#  <Reaction 3OAS60__Synechococcus at 0x35c3a3f70>,
#  <Reaction EAR40y__Synechococcus at 0x35c3aca60>,
#  <Reaction MG2uabcpp__Synechococcus at 0x35c212c40>,
#  <Reaction KARA1__Synechococcus at 0x35c428130>,
#  <Reaction TKT1__Synechococcus at 0x35c4603a0>,
#  <Reaction PTRCabcpp__Synechococcus at 0x35c49d100>,
#  <Reaction IPDDI__Synechococcus at 0x35c424340>,
#  <Reaction PKETF__Synechococcus at 0x35c3defd0>,
#  <Reaction ACODA__Synechococcus at 0x35c53deb0>,
#  <Reaction ENO__Synechococcus at 0x35c535490>,
#  <Reaction NDHPQRcm__Synechococcus at 0x35c5baac0>,
#  <Reaction NI2uabcpp__Synechococcus at 0x35c578b50>,
#  <Reaction Kabcpp__Synechococcus at 0x35c668af0>,
#  <Reaction TDPDRR__Synechococcus at 0x35cee8eb0>,
#  <Reaction UAGCVT__Synechococcus at 0x35c4d2040>,
#  <Reaction TDPGDH__Synechococcus at 0x35c9b7fd0>,
#  <Reaction PRASCSi__Synechococcus at 0x35d23ae20>,
#  <Reaction PRFGS__Synechococcus at 0x35cb60940>,
#  <Reaction MG2tex__Synechococcus at 0x35d5af520>,
#  <Reaction GLU5K__Synechococcus at 0x35d5a0b80>,
#  <Reaction TRDR__Synechococcus at 0x35d5cbe50>,
#  <Reaction GLUPRT__Synechococcus at 0x35d5fa5b0>,
#  <Reaction PSERT__Synechococcus at 0x35d558670>,
#  <Reaction PC8XM__Synechococcus at 0x35d9407f0>,
#  <Reaction GMPS2__Synechococcus at 0x35c82eeb0>,
#  <Reaction RBFK__Synechococcus at 0x35da543d0>,
#  <Reaction NTRIRfx__Synechococcus at 0x35da7c2b0>,
#  <Reaction UPP3MT__Synechococcus at 0x35da0a6d0>,
#  <Reaction ACS__Synechococcus at 0x35d5a9370>,
#  <Reaction DHNCOAS__Synechococcus at 0x35d6533d0>,
#  <Reaction MCOATA__Synechococcus at 0x35dafd1f0>,
#  <Reaction GTHPi__Synechococcus at 0x35db30340>,
#  <Reaction ARGSS__Synechococcus at 0x35db6a550>,
#  <Reaction PKETX__Synechococcus at 0x35dbcf400>,
#  <Reaction PMPK__Synechococcus at 0x35dbdebe0>,
#  <Reaction HMBS__Synechococcus at 0x35da81a60>,
#  <Reaction PTPATi__Synechococcus at 0x35dc4be20>,
#  <Reaction PGLYCP__Synechococcus at 0x35dc859a0>,
#  <Reaction HTHRPDH__Synechococcus at 0x35db9cf10>,
#  <Reaction UAGAAT2__Synechococcus at 0x35dc4b9d0>,
#  <Reaction SPTc__Synechococcus at 0x35dd34820>,
#  <Reaction GTHOr__Synechococcus at 0x35dcf9df0>,
#  <Reaction TDPDRE__Synechococcus at 0x35ddc44f0>,
#  <Reaction SHK3Dr__Synechococcus at 0x35daaa2b0>,
#  <Reaction ORPT__Synechococcus at 0x35dde54f0>,
#  <Reaction PRPPS__Synechococcus at 0x35e2c7160>,
#  <Reaction CITMS__Synechococcus at 0x35de15f40>,
#  <Reaction BCT1_syn__Synechococcus at 0x35dd68130>,
#  <Reaction SPODM__Synechococcus at 0x35e692160>,
#  <Reaction TRDRf__Synechococcus at 0x35e5d7dc0>,
#  <Reaction AMPTASECG__Synechococcus at 0x35e6e1040>,
#  <Reaction SPRMS__Synechococcus at 0x35e6f9040>,
#  <Reaction PGAMT__Synechococcus at 0x35ea28370>,
#  <Reaction NNDPR__Synechococcus at 0x35ef33070>,
#  <Reaction ADSK__Synechococcus at 0x35f5aeb80>,
#  <Reaction MECDPS__Synechococcus at 0x35ef2f2e0>,
#  <Reaction FCLT__Synechococcus at 0x35ef52e20>,
#  <Reaction SHCHCS3__Synechococcus at 0x35f289dc0>,
#  <Reaction PPA__Synechococcus at 0x349d38ee0>,
#  <Reaction ADCYRS__Synechococcus at 0x349dbd1c0>,
#  <Reaction ATPPRT__Synechococcus at 0x35d265430>,
#  <Reaction CUabcpp__Synechococcus at 0x35f5e24f0>,
#  <Reaction DHQS__Synechococcus at 0x35f76e6d0>,
#  <Reaction GTHRDH_syn__Synechococcus at 0x35f7ba3a0>,
#  <Reaction ANPRT__Synechococcus at 0x35fbb9100>,
#  <Reaction PC6AR_1__Synechococcus at 0x35fbc7e80>,
#  <Reaction ADK1__Synechococcus at 0x35fd19e20>,
#  <Reaction PRAIi__Synechococcus at 0x3603e9130>,
#  <Reaction TRSARyr__Synechococcus at 0x36009d370>,
#  <Reaction CYNTtabcpp__Synechococcus at 0x3606510a0>,
#  <Reaction RBPCcx__Synechococcus at 0x3607a7550>,
#  <Reaction UPP3S__Synechococcus at 0x360850100>,
#  <Reaction DHNPA_1__Synechococcus at 0x360845e20>,
#  <Reaction MOBDabcpp__Synechococcus at 0x35ffa3310>,
#  <Reaction NADK__Synechococcus at 0x360d22040>,
#  <Reaction BIOMASS_RNA__Synechococcus at 0x360be9f10>,
#  <Reaction NADTRHD__Synechococcus at 0x360be9be0>,
#  <Reaction PGM__Synechococcus at 0x36108f850>,
#  <Reaction FE3abcpp__Synechococcus at 0x361065700>,
#  <Reaction DM_dialurate_c__Synechococcus at 0x361ac7400>,
#  <Reaction CO2tex__Synechococcus at 0x3619ce0a0>,
#  <Reaction USHD2__Synechococcus at 0x361a9ae80>,
#  <Reaction DHNCOAT__Synechococcus at 0x36103fa90>,
#  <Reaction NPHBDC__Synechococcus at 0x361408e50>,
#  <Reaction DM_co_c__Synechococcus at 0x361df2790>,
#  <Reaction HCO3E_1_cx__Synechococcus at 0x361094d30>,
#  <Reaction DESAT16a__Synechococcus at 0x362133c40>,
#  <Reaction UAGDP__Synechococcus at 0x360f382e0>,
#  <Reaction BIOMASS_CARB__Synechococcus at 0x3621622b0>,
#  <Reaction EX_fe2_e__Synechococcus at 0x362133dc0>,
#  <Reaction PQH2tcm__Synechococcus at 0x3624f73a0>,
#  <Reaction 2PGLYCtcx__Synechococcus at 0x362804f40>,
#  <Reaction PDS1_1__Synechococcus at 0x362804fa0>,
#  <Reaction EX_cu2_e__Synechococcus at 0x3628231c0>,
#  <Reaction FRTT__Synechococcus at 0x362830e50>,
#  <Reaction 3OAS180__Synechococcus at 0x362838160>,
#  <Reaction EAR80y__Synechococcus at 0x36284d130>,
#  <Reaction DM_5drib_c__Synechococcus at 0x36285beb0>,
#  <Reaction SK_amylose_c__Synechococcus at 0x36284dac0>,
#  <Reaction EAR140y__Synechococcus at 0x362860820>,
#  <Reaction EX_k_e__Synechococcus at 0x36288e250>,
#  <Reaction ACGS__Synechococcus at 0x3628b3400>,
#  <Reaction CYTBD4um__Synechococcus at 0x3628d6c70>,
#  <Reaction DHPPDA__Synechococcus at 0x3628fa1f0>,
#  <Reaction DHFR__Synechococcus at 0x3628d6d00>,
#  <Reaction BCAROHX__Synechococcus at 0x3628fee80>,
#  <Reaction SK_14glucan_c__Synechococcus at 0x36292e2e0>,
#  <Reaction SK_glycogen_c__Synechococcus at 0x3628db5e0>,
#  <Reaction EX_h2o_e__Synechococcus at 0x362d7ab20>,
#  <Reaction EX_o2_e__Synechococcus at 0x362d93be0>,
#  <Reaction EX_co2_e__Synechococcus at 0x362da8220>,
#  <Reaction EX_leu__L_e__Synechococcus at 0x362da85e0>,
#  <Reaction MPOMC1_1__Synechococcus at 0x362dd2190>,
#  <Reaction ERTHMMOR__Synechococcus at 0x362dd26a0>,
#  <Reaction EX_cobalt2_e__Synechococcus at 0x362dd70d0>,
#  <Reaction EX_no3_e__Synechococcus at 0x362de83a0>,
#  <Reaction EX_zn2_e__Synechococcus at 0x362dfb160>,
#  <Reaction EX_fe3_e__Synechococcus at 0x362dfb9d0>,
#  <Reaction EX_so4_e__Synechococcus at 0x362e01730>,
#  <Reaction AFAT__Synechococcus at 0x362e24490>,
#  <Reaction EX_spmd_e__Synechococcus at 0x362e24700>,
#  <Reaction EX_mobd_e__Synechococcus at 0x362e29640>,
#  <Reaction DADK__Synechococcus at 0x362e48310>,
#  <Reaction G1SAT__Synechococcus at 0x362e4d310>,
#  <Reaction EX_ni2_e__Synechococcus at 0x362e4d100>,
#  <Reaction UAAGDS__Synechococcus at 0x362e4d790>,
#  <Reaction HEX1__Synechococcus at 0x362e72040>,
#  <Reaction URIDK2r__Synechococcus at 0x362e76850>,
#  <Reaction CHPHYS__Synechococcus at 0x362ea25e0>,
#  <Reaction EX_na1_e__Synechococcus at 0x363011190>,
#  <Reaction PIuabcpp__Synechococcus at 0x362edc9d0>,
#  <Reaction ARGDHpp__Synechococcus at 0x363052880>,
#  <Reaction PHETA1__Synechococcus at 0x36301f730>,
#  <Reaction PFK__Synechococcus at 0x36306d760>,
#  <Reaction DMPPS_syn__Synechococcus at 0x36308d760>,
#  <Reaction ANS2__Synechococcus at 0x363059670>,
#  <Reaction 3OAS160__Synechococcus at 0x36353dcd0>,
#  <Reaction ACHBSb__Synechococcus at 0x363052550>,
#  <Reaction PC20M__Synechococcus at 0x3635433a0>,
#  <Reaction ADSS__Synechococcus at 0x36351f610>,
#  <Reaction THRPDC__Synechococcus at 0x36358fa90>,
#  <Reaction MPOMOR_1__Synechococcus at 0x3637fb280>,
#  <Reaction EX_cynt_e__Synechococcus at 0x3635c1130>,
#  <Reaction IPPMIa__Synechococcus at 0x363c096d0>,
#  <Reaction SPMS__Synechococcus at 0x363d3e5b0>,
#  <Reaction EX_h_e__Synechococcus at 0x363d1adc0>,
#  <Reaction BPNT__Synechococcus at 0x363d39ca0>,
#  <Reaction ICDHyr__Synechococcus at 0x363d8c1c0>,
#  <Reaction TMDS3__Synechococcus at 0x363d63b80>,
#  <Reaction GLYOX_1__Synechococcus at 0x363db5460>,
#  <Reaction MTRI__Synechococcus at 0x36411abb0>,
#  <Reaction CTPS2__Synechococcus at 0x3644f86d0>,
#  <Reaction FE3tex__Synechococcus at 0x3643b8370>,
#  <Reaction GTHS__Synechococcus at 0x3644f8d00>,
#  <Reaction AHSERL2_1__Synechococcus at 0x364546eb0>,
#  <Reaction PEPC__Synechococcus at 0x3645500a0>,
#  <Reaction CHORM__Synechococcus at 0x363d91190>,
#  <Reaction NTRARf2__Synechococcus at 0x3645b3070>,
#  <Reaction FE2tex__Synechococcus at 0x364546160>,
#  <Reaction G6PDA__Synechococcus at 0x36458a070>,
#  <Reaction MPML__Synechococcus at 0x364614e20>,
#  <Reaction Nat_Kpp__Synechococcus at 0x36464b8e0>,
#  <Reaction PDH__Synechococcus at 0x364614a90>,
#  <Reaction TPI__Synechococcus at 0x36472bca0>,
#  <Reaction E4PD__Synechococcus at 0x364685b50>,
#  <Reaction GAPD__Synechococcus at 0x3646f13d0>,
#  <Reaction CPPPGO__Synechococcus at 0x364b376d0>,
#  <Reaction PRMICI__Synechococcus at 0x3646438b0>,
#  <Reaction CAT__Synechococcus at 0x364d98910>,
#  <Reaction GLUR__Synechococcus at 0x364eabee0>,
#  <Reaction OCBT__Synechococcus at 0x365895040>,
#  <Reaction NI2tex__Synechococcus at 0x36467d730>,
#  <Reaction GLGC__Synechococcus at 0x3651ca5b0>,
#  <Reaction PYK__Synechococcus at 0x3658ef880>,
#  <Reaction CA2t2pp__Synechococcus at 0x3658cbdc0>,
#  <Reaction ALAR__Synechococcus at 0x365917df0>,
#  <Reaction SULR_2__Synechococcus at 0x3651ca8b0>,
#  <Reaction ADCS__Synechococcus at 0x36598f370>,
#  <Reaction UGMDDS__Synechococcus at 0x3658f4820>,
#  <Reaction GLCDBRAN3__Synechococcus at 0x3659e5f70>,
#  <Reaction IG3PS__Synechococcus at 0x365a1ee50>,
#  <Reaction RPI__Synechococcus at 0x365a58be0>,
#  <Reaction NAt3pp__Synechococcus at 0x3659ec8e0>,
#  <Reaction MNtex__Synechococcus at 0x365e0b820>,
#  <Reaction GLYCLTDx__Synechococcus at 0x365a63f40>,
#  <Reaction FMNRy_1__Synechococcus at 0x3665879d0>,
#  <Reaction GHMT2r__Synechococcus at 0x366299f40>,
#  <Reaction COBALT2tex__Synechococcus at 0x3662be0d0>,
#  <Reaction PGPP_OLE_PALM__Synechococcus at 0x366293cd0>,
#  <Reaction CU2tex__Synechococcus at 0x36656e2b0>,
#  <Reaction MEOHtrpp__Synechococcus at 0x366a45730>,
#  <Reaction MEOHtex__Synechococcus at 0x366a45bb0>,
#  <Reaction H2Otcx__Synechococcus at 0x366827280>,
#  <Reaction Zn2tex__Synechococcus at 0x366a6a6a0>,
#  <Reaction EX_photon410_e__Synechococcus at 0x366a6a9d0>,
#  <Reaction EX_photon430_e__Synechococcus at 0x366a70850>,
#  <Reaction EX_photon450_e__Synechococcus at 0x366a70d60>,
#  <Reaction EX_photon470_e__Synechococcus at 0x366a8f040>,
#  <Reaction EX_photon490_e__Synechococcus at 0x366a93640>,
#  <Reaction EX_photon510_e__Synechococcus at 0x366a93880>,
#  <Reaction DM_amob_c__Synechococcus at 0x366a93970>,
#  <Reaction ADNK1__Synechococcus at 0x366a93a30>,
#  <Reaction OPMEACPD__Synechococcus at 0x366a93ac0>,
#  <Reaction OPMEACPR__Synechococcus at 0x366a93be0>,
#  <Reaction EX_photon530_e__Synechococcus at 0x366a93cd0>,
#  <Reaction EX_photon550_e__Synechococcus at 0x366a93e50>,
#  <Reaction SPP__Synechococcus at 0x366a9d0d0>,
#  <Reaction SPMDtex__Synechococcus at 0x366a9d940>,
#  <Reaction AGPAT160__Synechococcus at 0x366a9d400>,
#  <Reaction EX_photon570_e__Synechococcus at 0x366aa1520>,
#  <Reaction EX_photon590_e__Synechococcus at 0x366aca790>,
#  <Reaction EX_photon610_e__Synechococcus at 0x366aee310>,
#  <Reaction AGPATACP_HDE_PALM__Synechococcus at 0x366af3370>,
#  <Reaction LEUtex__Synechococcus at 0x366b0ec10>,
#  <Reaction BTS6__Synechococcus at 0x366b183d0>,
#  <Reaction QUERT__Synechococcus at 0x366b18910>,
#  <Reaction EX_photon630_e__Synechococcus at 0x366b406d0>,
#  <Reaction EX_photon650_e__Synechococcus at 0x366b401c0>,
#  <Reaction EX_photon670_e__Synechococcus at 0x366ba4af0>,
#  <Reaction EX_photon690_e__Synechococcus at 0x366f84850>,
#  <Reaction PMEACPE__Synechococcus at 0x366f84c70>,
#  <Reaction G3PAT160__Synechococcus at 0x366f84f40>,
#  <Reaction GLUDGE_HDE_HDE__Synechococcus at 0x366dd90d0>,
#  <Reaction G3PAT161__Synechococcus at 0x366f84eb0>,
#  <Reaction HCO3tex__Synechococcus at 0x366fd0910>,
#  <Reaction G3PAT1819Z_1__Synechococcus at 0x366f84e80>,
#  <Reaction EPMEACPR__Synechococcus at 0x367000070>,
#  <Reaction GLUDGE_OLE_HDE__Synechococcus at 0x367387b50>,
#  <Reaction GLUDGE_OLE_PALM__Synechococcus at 0x367382490>,
#  <Reaction GLUDGE_HDE_PALM__Synechococcus at 0x367701e80>,
#  <Reaction GLNtex__Synechococcus at 0x367a27d60>,
#  <Reaction AGPAT161__Synechococcus at 0x367a56df0>,
#  <Reaction AGPATACP_OLE_HDE__Synechococcus at 0x367a7fd00>,
#  <Reaction AGPATACP_OLE_PALM__Synechococcus at 0x367a89460>,
#  <Reaction GLUDGS_OLE_HDE__Synechococcus at 0x367a8d520>,
#  <Reaction CYNTtex__Synechococcus at 0x367ab7280>,
#  <Reaction GLUDGS_OLE_PALM__Synechococcus at 0x367a607f0>,
#  <Reaction GLUDGS_HDE_PALM__Synechococcus at 0x367b00250>,
#  <Reaction ARGtex__Synechococcus at 0x367b28f10>,
#  <Reaction GLUDGS_HDE_HDE__Synechococcus at 0x367b044f0>,
#  <Reaction TYRTRS__Synechococcus at 0x367b57850>,
#  <Reaction DAGK160__Synechococcus at 0x367b4d910>,
#  <Reaction MOBDtex__Synechococcus at 0x367bc6340>,
#  <Reaction DAGK_HDE_PALM__Synechococcus at 0x367b7dfd0>,
#  <Reaction DAGK161__Synechococcus at 0x367bf2be0>,
#  <Reaction NH4tex__Synechococcus at 0x367c2cd30>,
#  <Reaction SQDGS_PALM_PALM__Synechococcus at 0x367bfc160>,
#  <Reaction SO4tex__Synechococcus at 0x367c67fa0>,
#  <Reaction SQDGS_HDE_PALM__Synechococcus at 0x367c36070>,
#  <Reaction PGPS_OLE_PALM__Synechococcus at 0x367ca9430>,
#  <Reaction DGDGS_HDE_PALM__Synechococcus at 0x367cdaac0>,
#  <Reaction PTRCtex__Synechococcus at 0x367ce3bb0>,
#  <Reaction DGDGS_HDE_HDE__Synechococcus at 0x367cdac40>,
#  <Reaction NO3tex__Synechococcus at 0x367d4fee0>,
#  <Reaction DGDGS_OLE_HDE__Synechococcus at 0x367d1e970>,
#  <Reaction DGDGS_OLE_PALM__Synechococcus at 0x367d8b910>,
#  <Reaction CDPDAGS_OLE_PALM__Synechococcus at 0x367d57c40>,
#  <Reaction GLNTRS__Synechococcus at 0x367dcd8b0>,
#  <Reaction METTRS__Synechococcus at 0x367e427f0>,
#  <Reaction SERTRS__Synechococcus at 0x367e07b80>,
#  <Reaction NAtex__Synechococcus at 0x367e8e7c0>,
#  <Reaction PROTRS__Synechococcus at 0x367dfea00>,
#  <Reaction GLYTRS__Synechococcus at 0x367f20e20>,
#  <Reaction CYSTRS__Synechococcus at 0x3681f20d0>,
#  <Reaction CA2tex__Synechococcus at 0x367f35070>,
#  <Reaction ARGTRS__Synechococcus at 0x367e74490>,
#  <Reaction Ktex__Synechococcus at 0x36840ba60>,
#  <Reaction TRPTRS__Synechococcus at 0x367e748e0>,
#  <Reaction HISTRS__Synechococcus at 0x36843a040>,
#  <Reaction CO2tpp__Synechococcus at 0x36843e0d0>,
#  <Reaction PHETRS__Synechococcus at 0x368434c10>,
#  <Reaction EX_pi_e__Synechococcus at 0x368783070>,
#  <Reaction ASNTRS__Synechococcus at 0x368355910>,
#  <Reaction ASPTRS__Synechococcus at 0x368912370>,
#  <Reaction UDPGLDC__Synechococcus at 0x36893b070>,
#  <Reaction PItex__Synechococcus at 0x3689937f0>,
#  <Reaction AGTi__Synechococcus at 0x368927100>,
#  <Reaction DBTS__Synechococcus at 0x368624190>,
#  <Reaction THRTRS__Synechococcus at 0x368d513a0>,
#  <Reaction LEUTRS__Synechococcus at 0x368d567f0>,
#  <Reaction ILETRS__Synechococcus at 0x368d7aaf0>,
#  <Reaction CHLADMT_1__Synechococcus at 0x368da3310>,
#  <Reaction LYSTRS__Synechococcus at 0x368d3d1c0>,
#  <Reaction AOXSr2__Synechococcus at 0x368df0d90>,
#  <Reaction AMAOTr__Synechococcus at 0x368e1aee0>,
#  <Reaction LIPOS2__Synechococcus at 0x368e20e50>,
#  <Reaction ALATRS__Synechococcus at 0x368df7310>,
#  <Reaction TRNFE__Synechococcus at 0x368e48f40>,
#  <Reaction VALTRS__Synechococcus at 0x368e7df40>,
#  <Reaction FMETTRS__Synechococcus at 0x368f23d30>,
#  <Reaction BACCL__Synechococcus at 0x368f6f0a0>,
#  <Reaction BTNPL2__Synechococcus at 0x368e7d0d0>,
#  <Reaction LIPAMPL_1__Synechococcus at 0x36923a340>,
#  <Reaction LIPOCT__Synechococcus at 0x3693afeb0>,
#  <Reaction LIPATPT_1__Synechococcus at 0x3692c8580>,
#  <Reaction ZXANHX__Synechococcus at 0x36938b9d0>,
#  <Reaction PHOA410um__Synechococcus at 0x3693c92e0>,
#  <Reaction PHOA430um__Synechococcus at 0x369447a30>,
#  <Reaction CPH4S__Synechococcus at 0x36982e430>,
#  <Reaction OGMEACPR__Synechococcus at 0x3696d0640>,
#  <Reaction CDGS__Synechococcus at 0x369752550>,
#  <Reaction PHOA450um__Synechococcus at 0x369877820>,
#  <Reaction PHOA470um__Synechococcus at 0x369865220>,
#  <Reaction PHOA490um__Synechococcus at 0x36988d520>,
#  <Reaction CCGS__Synechococcus at 0x3698a06a0>,
#  <Reaction CDGR__Synechococcus at 0x3698c5f70>,
#  <Reaction PHOA510um__Synechococcus at 0x3698eeeb0>,
#  <Reaction PHOA530um__Synechococcus at 0x3698ca3d0>,
#  <Reaction PLYCOI__Synechococcus at 0x3698f3730>,
#  <Reaction PHOA550um__Synechococcus at 0x369921400>,
#  <Reaction SAMTRI__Synechococcus at 0x369912280>,
#  <Reaction EPXQR__Synechococcus at 0x36991c460>,
#  <Reaction UPPRT__Synechococcus at 0x369946280>,
#  <Reaction PHOA570um__Synechococcus at 0x36996e1f0>,
#  <Reaction PHOA590um__Synechococcus at 0x36991c610>,
#  <Reaction PHOA610um__Synechococcus at 0x369d8b640>,
#  <Reaction ZCARDS__Synechococcus at 0x369d8bf40>,
#  <Reaction PHOA630um__Synechococcus at 0x369daaa00>,
#  <Reaction PHOA650um__Synechococcus at 0x369daa160>,
#  <Reaction PHOA670um__Synechococcus at 0x369db0a60>,
#  <Reaction UDPGD__Synechococcus at 0x369dd3880>,
#  <Reaction GMAND__Synechococcus at 0x369dd3d60>,
#  <Reaction GFUCS__Synechococcus at 0x369df7070>,
#  <Reaction PHOA690um__Synechococcus at 0x369dfd910>,
#  <Reaction NADDP__Synechococcus at 0x369f03d60>,
#  <Reaction DM_pho_loss_c__Synechococcus at 0x369f2ca90>,
#  <Reaction ETCHLAS__Synechococcus at 0x369f26880>,
#  <Reaction ETBCARO__Synechococcus at 0x369f4fdc0>,
#  <Reaction COLIPAabcex__Synechococcus at 0x369f793a0>,
#  <Reaction MLDCP1App__Synechococcus at 0x369f79af0>,
#  <Reaction CDPGLC46DH__Synechococcus at 0x369f9d250>,
#  <Reaction AACPS6__Synechococcus at 0x369fa1850>,
#  <Reaction ALDR18__Synechococcus at 0x369fa1ac0>,
#  <Reaction ALDDC17__Synechococcus at 0x369fafa00>,
#  <Reaction ALCD19__Synechococcus at 0x369fa1580>,
#  <Reaction THZT__Synechococcus at 0x36a00ea30>,
#  <Reaction MLDCP1Bpp__Synechococcus at 0x369fa66d0>,
#  <Reaction PHYPQOX__Synechococcus at 0x36a04a850>,
#  <Reaction MLDCP2App__Synechococcus at 0x36a0f73a0>,
#  <Reaction MLDCP2Bpp__Synechococcus at 0x36a517970>,
#  <Reaction LALGP__Synechococcus at 0x36a517d90>,
#  <Reaction AGM4Pt2pp__Synechococcus at 0x36a2ffee0>,
#  <Reaction AGMt2pp__Synechococcus at 0x36a529220>,
#  <Reaction CXANHX__Synechococcus at 0x36a533340>,
#  <Reaction OGMEACPS__Synechococcus at 0x36a5383d0>,
#  <Reaction A5PISO__Synechococcus at 0x36a552610>,
#  <Reaction KDOPS__Synechococcus at 0x36a55c040>,
#  <Reaction KDOPP__Synechococcus at 0x36a560490>,
#  <Reaction EX_meoh_e__Synechococcus at 0x36a5874c0>,
#  <Reaction NO2tex__Synechococcus at 0x36a533640>,
#  <Reaction KDOCT2__Synechococcus at 0x36a5f75b0>,
#  <Reaction EGMEACPR__Synechococcus at 0x36a5fcd60>,
#  <Reaction DXYTST__Synechococcus at 0x36a6204c0>,
#  <Reaction UAG2E__Synechococcus at 0x36a64d250>,
#  <Reaction OANTS__Synechococcus at 0x36a656c70>,
#  <Reaction ACGAMT__Synechococcus at 0x36a6d5d90>,
#  <Reaction Htabcpp__Synechococcus at 0x36a6ff340>,
#  <Reaction ETAPCPSII__Synechococcus at 0x36a6ccb50>,
#  <Reaction STCHLPSIum__Synechococcus at 0x36a741970>,
#  <Reaction DEXZEAX__Synechococcus at 0x36a787250>,
#  <Reaction PFOR__Synechococcus at 0x36a78e580>,
#  <Reaction ACMAMT__Synechococcus at 0x36ab9df40>,
#  <Reaction ICLIPAabcpp__Synechococcus at 0x36aa6a250>,
#  <Reaction ICLIPAS__Synechococcus at 0x36aa8d0d0>,
#  <Reaction MOAT_1__Synechococcus at 0x36abe62b0>,
#  <Reaction MPTG__Synechococcus at 0x36abf06d0>,
#  <Reaction MPTG2__Synechococcus at 0x36abc1b80>,
#  <Reaction UAGPT3__Synechococcus at 0x36abf01c0>,
#  <Reaction GLYCOX1__Synechococcus at 0x36aa8d400>,
#  <Reaction UM4PL__Synechococcus at 0x36abea340>,
#  <Reaction UM3PL__Synechococcus at 0x36b5b0310>,
#  <Reaction PAPPT3__Synechococcus at 0x36b9dcbb0>,
#  <Reaction OANTIabcpp__Synechococcus at 0x36b9b7160>,
#  <Reaction OANTILpp__Synechococcus at 0x36b6a29a0>,
#  <Reaction MDDCP1pp__Synechococcus at 0x36ba5dbb0>,
#  <Reaction MDDCP2pp__Synechococcus at 0x36ba3e160>,
#  <Reaction STACPSI__Synechococcus at 0x36ac0fee0>,
#  <Reaction UDCPDP__Synechococcus at 0x36bade100>,
#  <Reaction MLTGY1pp__Synechococcus at 0x36bf765b0>,
#  <Reaction ETCPC__Synechococcus at 0x36bf78af0>,
#  <Reaction GLYCOX2__Synechococcus at 0x36c9d10d0>,
#  <Reaction NO2tabcpp__Synechococcus at 0x36c9c3730>,
#  <Reaction MLTGY2pp__Synechococcus at 0x36c9ac6a0>,
#  <Reaction MLTGY3pp__Synechococcus at 0x36c9c3cd0>,
#  <Reaction MLTGY4pp__Synechococcus at 0x36c9ccd00>,
#  <Reaction AGM4PA__Synechococcus at 0x36cd9c7f0>,
#  <Reaction FALGTHLs__Synechococcus at 0x36cdca7c0>,
#  <Reaction CLtex__Synechococcus at 0x36d223fd0>,
#  <Reaction EX_cl_e__Synechococcus at 0x36d228ac0>,
#  <Reaction AM3PA__Synechococcus at 0x36d2511f0>,
#  <Reaction AM4PA__Synechococcus at 0x36d2572e0>,
#  <Reaction SK_fum_c__Synechococcus at 0x36d2683d0>,
#  <Reaction MALCOAMT__Synechococcus at 0x36d27b040>,
#  <Reaction DM_succ_c__Synechococcus at 0x36d29fc40>,
#  <Reaction AGM3PApp__Synechococcus at 0x36d27b160>,
#  <Reaction AGM4PApp__Synechococcus at 0x36d2c4a60>,
#  <Reaction UM4PCP__Synechococcus at 0x36d2ce0d0>,
#  <Reaction SK_akg_c__Synechococcus at 0x36d2f2e80>,
#  <Reaction MDRPD__Synechococcus at 0x36d2a6a90>,
#  <Reaction NGAM_D1um__Synechococcus at 0x36d2fd220>,
#  <Reaction PSICRum__Synechococcus at 0x36d3711c0>,
#  <Reaction AM4PCP__Synechococcus at 0x36d359130>,
#  <Reaction 4PCP__Synechococcus at 0x36d3972e0>,
#  <Reaction AGM4PCP__Synechococcus at 0x36d3ab130>,
#  <Reaction AGMH__Synechococcus at 0x36d3d10a0>,
#  <Reaction PSIICRum__Synechococcus at 0x36d3e70d0>,
#  <Reaction DM_ac_c__Synechococcus at 0x36d4071c0>,
#  <Reaction AGM3PH__Synechococcus at 0x36d4451c0>,
#  <Reaction DM_lac__D_c__Synechococcus at 0x36d469550>,
#  <Reaction ENOPH__Synechococcus at 0x36d472c10>,
#  <Reaction NGAM__Synechococcus at 0x36d4a4460>,
#  <Reaction QULNS__Synechococcus at 0x36d472130>,
#  <Reaction AGM4PH__Synechococcus at 0x36d4de370>,
#  <Reaction LADGMDH__Synechococcus at 0x36d4e6be0>,
#  <Reaction ILETA__Synechococcus at 0x36d4f0cd0>,
#  <Reaction ALAGLUE__Synechococcus at 0x36d52adc0>,
#  <Reaction CELLSYN__Synechococcus at 0x36d55ac40>,
#  <Reaction ALAALAabcpp__Synechococcus at 0x36d61aa00>,
#  <Reaction LEUTA__Synechococcus at 0x36d685160>,
#  <Reaction ARD__Synechococcus at 0x36d60aac0>,
#  <Reaction VALTA__Synechococcus at 0x36d6b8dc0>,
#  <Reaction NDPK3__Synechococcus at 0x36d6cb0d0>,
#  <Reaction NDPK6__Synechococcus at 0x36d685a30>,
#  <Reaction NDPK1__Synechococcus at 0x36de2e760>,
#  <Reaction 4PEPTabcpp__Synechococcus at 0x36d6b8fd0>,
#  <Reaction ALAALAD__Synechococcus at 0x36df341c0>,
#  <Reaction ADPGLC__Synechococcus at 0x36df29f40>,
#  <Reaction NDPK8__Synechococcus at 0x36df0a2e0>,
#  <Reaction UNK3__Synechococcus at 0x36dedcaf0>,
#  <Reaction NDPK5__Synechococcus at 0x36df452b0>,
#  <Reaction DALAabcpp__Synechococcus at 0x36e278760>,
#  <Reaction NDPK4__Synechococcus at 0x36e3de340>,
#  <Reaction ZISO__Synechococcus at 0x36e3f94f0>,
#  <Reaction NDPK2__Synechococcus at 0x36e3e4af0>,
#  <Reaction 3OAR180__Synechococcus at 0x36e3e8400>,
#  <Reaction 3OAR140__Synechococcus at 0x36e45e970>,
#  <Reaction PAPA160__Synechococcus at 0x36e3bf520>,
#  <Reaction PHEOASE__Synechococcus at 0x36e835d00>,
#  <Reaction PAPA_HDE_PALM__Synechococcus at 0x36e85e760>,
#  <Reaction PAPA161__Synechococcus at 0x36e3bac10>,
#  <Reaction PAPA_OLE_HDE__Synechococcus at 0x36e8ab910>,
#  <Reaction ACGK__Synechococcus at 0x36e67ee20>,
#  <Reaction MCTP2App__Synechococcus at 0x36e923fa0>,
#  <Reaction MCTP1App__Synechococcus at 0x36e8d3460>,
#  <Reaction MCTP1Bpp__Synechococcus at 0x36e927910>,
#  <Reaction LEUabcpp__Synechococcus at 0x36e858970>,
#  <Reaction ACLSa__Synechococcus at 0x36f1b8130>,
#  <Reaction SULabcpp__Synechococcus at 0x36e9913d0>,
#  <Reaction PAPA_OLE_PALM__Synechococcus at 0x36ee43fa0>,
#  <Reaction TYRTA__Synechococcus at 0x36f075fa0>,
#  <Reaction ACLSb__Synechococcus at 0x36f8570d0>,
#  <Reaction PHEOX_1__Synechococcus at 0x36fea7070>,
#  <Reaction OPMEACPS__Synechococcus at 0x36fb60eb0>,
#  <Reaction EAR100y__Synechococcus at 0x36fe75940>,
#  <Reaction EHGLAT__Synechococcus at 0x36ff035b0>,
#  <Reaction KAS15__Synechococcus at 0x37037b910>,
#  <Reaction FALDH2__Synechococcus at 0x37027a2b0>,
#  <Reaction PHYTK__Synechococcus at 0x3703f5550>,
#  <Reaction NDH_1_4_um_copy2__Synechococcus at 0x3703d7040>,
#  <Reaction KARI_1__Synechococcus at 0x370498040>,
#  <Reaction 3HAD120__Synechococcus at 0x370498130>,
#  <Reaction OGMEACPD__Synechococcus at 0x370479eb0>,
#  <Reaction ACCOAC__Synechococcus at 0x370451b50>,
#  <Reaction ASPO5__Synechococcus at 0x3708684f0>,
#  <Reaction PTHPS__Synechococcus at 0x370428c10>,
#  <Reaction CITCIa__Synechococcus at 0x370479d60>,
#  <Reaction DAGK_OLE_HDE__Synechococcus at 0x370949a00>,
#  <Reaction DAGK_OLE_PALM__Synechococcus at 0x370818340>,
#  <Reaction 3HAD100__Synechococcus at 0x3708e43a0>,
#  <Reaction PNTK__Synechococcus at 0x370ce9760>,
#  <Reaction 3OAR120__Synechococcus at 0x370818a90>,
#  <Reaction 3OAR60__Synechococcus at 0x370936f40>,
#  <Reaction 3OAR100__Synechococcus at 0x370d13700>,
#  <Reaction 3OAR80__Synechococcus at 0x3710e9af0>,
#  <Reaction ALCD1__Synechococcus at 0x370818160>,
#  <Reaction NDH_1_1_um_copy1__Synechococcus at 0x371136910>,
#  <Reaction NDH_1_4_um_copy1__Synechococcus at 0x37113bd30>,
#  <Reaction PCHLDA430__Synechococcus at 0x371599250>,
#  <Reaction SFGTHi__Synechococcus at 0x371589940>,
#  <Reaction PCHLDA650__Synechococcus at 0x3711b2760>,
#  <Reaction GGCLUT2__Synechococcus at 0x3710938e0>,
#  <Reaction SPR__Synechococcus at 0x371609a30>,
#  <Reaction OPAH__Synechococcus at 0x371bab130>,
#  <Reaction ACGAMK__Synechococcus at 0x371dc21c0>,
#  <Reaction AMANAPEr__Synechococcus at 0x371e0a550>,
#  <Reaction AGDC__Synechococcus at 0x371e180d0>,
#  <Reaction ANHMK__Synechococcus at 0x371e3e3a0>,
#  <Reaction RNDR4__Synechococcus at 0x371e61d00>,
#  <Reaction TRPS2__Synechococcus at 0x371ec2ac0>,
#  <Reaction PSICSum__Synechococcus at 0x371eb4790>,
#  <Reaction NAD_H2__Synechococcus at 0x371f97100>,
#  <Reaction PPND__Synechococcus at 0x371e61f40>,
#  <Reaction CBFCum__Synechococcus at 0x371fcaaf0>,
#  <Reaction ACM6PH__Synechococcus at 0x372b8b1c0>,
#  <Reaction SUCR__Synechococcus at 0x372b101f0>,
#  <Reaction CLt3_1pp__Synechococcus at 0x372b829d0>,
#  <Reaction Ktu__Synechococcus at 0x372ee8cd0>,
#  <Reaction THBTGT__Synechococcus at 0x372b8b580>,
#  <Reaction FDH6__Synechococcus at 0x372f015b0>,
#  <Reaction PCXHtpp__Synechococcus at 0x372b10340>,
#  <Reaction THISAT__Synechococcus at 0x372f7e220>,
#  <Reaction PSIIum__Synechococcus at 0x372f0f790>,
#  <Reaction ATPSum__Synechococcus at 0x3732c8c70>,
#  <Reaction CYSDES__Synechococcus at 0x373b6ce50>,
#  <Reaction NO3abcpp__Synechococcus at 0x3733a00a0>,
#  <Reaction GLNabcpp__Synechococcus at 0x373b99b50>,
#  <Reaction GLNS__Synechococcus at 0x373ee0f70>,
#  <Reaction MDDEP1pp__Synechococcus at 0x3741d84c0>,
#  <Reaction THII__Synechococcus at 0x374521100>,
#  <Reaction SHS1__Synechococcus at 0x373ee6310>,
#  <Reaction PSIICSum__Synechococcus at 0x37456ebb0>,
#  <Reaction NDH_1_1_um_copy2__Synechococcus at 0x374888970>,
#  <Reaction ASNS1__Synechococcus at 0x374482370>,
#  <Reaction MDDCP3pp__Synechococcus at 0x375af8cd0>,
#  <Reaction MDDCP4pp__Synechococcus at 0x37561b220>,
#  <Reaction MDDCP5pp__Synechococcus at 0x37561b1c0>,
#  <Reaction MDDEP2pp__Synechococcus at 0x375e73190>,
#  <Reaction MDDEP3pp__Synechococcus at 0x3764d85e0>,
#  <Reaction MDDEP4pp__Synechococcus at 0x37561b370>,
#  <Reaction MNHNAtpp__Synechococcus at 0x3769189d0>,
#  <Reaction EX_sucr_e__Synechococcus at 0x377319250>,
#  <Reaction SUCRt2__Synechococcus at 0x3772fc550>,
#  <Reaction EX_gln__L_m at 0x376918ee0>,
#  <Reaction EX_hco3_m at 0x37561b130>,
#  <Reaction EX_mn2_m at 0x376fa7eb0>,
#  <Reaction EX_arg__L_m at 0x377664460>,
#  <Reaction EX_mg2_m at 0x377974be0>,
#  <Reaction EX_ptrc_m at 0x37798c190>,
#  <Reaction EX_ca2_m at 0x37798c220>,
#  <Reaction EX_nh4_m at 0x37798c550>,
#  <Reaction EX_fe2_m at 0x37798c5b0>,
#  <Reaction EX_cu2_m at 0x37798ca90>,
#  <Reaction EX_k_m at 0x37798cd90>,
#  <Reaction EX_h2o_m at 0x3779286a0>,
#  <Reaction EX_o2_m at 0x377928b20>,
#  <Reaction EX_co2_m at 0x3779a3d60>,
#  <Reaction EX_leu__L_m at 0x3779ad070>,
#  <Reaction EX_cobalt2_m at 0x3779ad2b0>,
#  <Reaction EX_no3_m at 0x3779ad3d0>,
#  <Reaction EX_zn2_m at 0x3779ad520>,
#  <Reaction EX_fe3_m at 0x3779ad5b0>,
#  <Reaction EX_so4_m at 0x3779ad640>,
#  <Reaction EX_spmd_m at 0x3779ad6d0>,
#  <Reaction EX_mobd_m at 0x3779ad760>,
#  <Reaction EX_ni2_m at 0x3779ad7f0>,
#  <Reaction EX_na1_m at 0x3779ad880>,
#  <Reaction EX_cynt_m at 0x3779ad910>,
#  <Reaction EX_h_m at 0x3779ad9a0>,
#  <Reaction EX_photon410_m at 0x3779ada30>,
#  <Reaction EX_photon430_m at 0x3779adac0>,
#  <Reaction EX_photon450_m at 0x3779adb50>,
#  <Reaction EX_photon470_m at 0x3779adbe0>,
#  <Reaction EX_photon490_m at 0x3779adc70>,
#  <Reaction EX_photon510_m at 0x3779add00>,
#  <Reaction EX_photon530_m at 0x3779add90>,
#  <Reaction EX_photon550_m at 0x3779ade20>,
#  <Reaction EX_photon570_m at 0x3779adeb0>,
#  <Reaction EX_photon590_m at 0x3779adf40>,
#  <Reaction EX_photon610_m at 0x3779adfd0>,
#  <Reaction EX_photon630_m at 0x3779b40a0>,
#  <Reaction EX_photon650_m at 0x3779b4130>,
#  <Reaction EX_photon670_m at 0x3779b41c0>,
#  <Reaction EX_photon690_m at 0x3779b4250>,
#  <Reaction EX_pi_m at 0x3779b42e0>,
#  <Reaction EX_meoh_m at 0x3779b4370>,
#  <Reaction EX_cl_m at 0x3779b4400>,
#  <Reaction EX_sucr_m at 0x3779b4490>,
#  <Reaction ALATA_D2__Azotobacter at 0x3779b4520>,
#  <Reaction SHCHD2__Azotobacter at 0x3779b46d0>,
#  <Reaction CPPPGO__Azotobacter at 0x3779bb160>,
#  <Reaction GTHOr__Azotobacter at 0x3779b4bb0>,
#  <Reaction DHORD5__Azotobacter at 0x377a05340>,
#  <Reaction GLYCTO2__Azotobacter at 0x377d3cb80>,
#  <Reaction GLYCTO3__Azotobacter at 0x377da4880>,
#  <Reaction GLYCTO4__Azotobacter at 0x377ddf820>,
#  <Reaction TRPS2__Azotobacter at 0x378195d00>,
#  <Reaction G3PD5__Azotobacter at 0x377d8db80>,
#  <Reaction EX_cellb_e__Azotobacter at 0x3784d4160>,
#  <Reaction EX_chol_e__Azotobacter at 0x3784f7910>,
#  <Reaction LEUTAi__Azotobacter at 0x3788414f0>,
#  <Reaction SHK3Dr__Azotobacter at 0x378b66280>,
#  <Reaction G5SD__Azotobacter at 0x378b7e3d0>,
#  <Reaction ALATA_L2__Azotobacter at 0x378b832e0>,
#  <Reaction APRAUR__Azotobacter at 0x378b89760>,
#  <Reaction DB4PS__Azotobacter at 0x378bd4d30>,
#  <Reaction RBFK__Azotobacter at 0x379347370>,
#  <Reaction ACP1_FMN__Azotobacter at 0x3793b6af0>,
#  <Reaction RBFSb__Azotobacter at 0x3793c9cd0>,
#  <Reaction EX_pi_e__Azotobacter at 0x3793eb8e0>,
#  <Reaction EX_h_e__Azotobacter at 0x3797620a0>,
#  <Reaction DMATT__Azotobacter at 0x37974cc10>,
#  <Reaction GRTT__Azotobacter at 0x379776f40>,
#  <Reaction UPP3S__Azotobacter at 0x37979f280>,
#  <Reaction UPPDC1__Azotobacter at 0x379771dc0>,
#  <Reaction EX_ade_e__Azotobacter at 0x379b5ee50>,
#  <Reaction EX_4abut_e__Azotobacter at 0x379e2f910>,
#  <Reaction EX_ac_e__Azotobacter at 0x379eaf760>,
#  <Reaction EX_akg_e__Azotobacter at 0x379eafbe0>,
#  <Reaction EX_ala__L_e__Azotobacter at 0x379ddab80>,
#  <Reaction EX_asp__L_e__Azotobacter at 0x379ed5a00>,
#  <Reaction EX_cytd_e__Azotobacter at 0x379edb880>,
#  <Reaction EX_dcyt_e__Azotobacter at 0x379edbc40>,
#  <Reaction EX_fum_e__Azotobacter at 0x379efa040>,
#  <Reaction EX_gua_e__Azotobacter at 0x379efe670>,
#  <Reaction HCO3E__Azotobacter at 0x379efe8b0>,
#  <Reaction IMPC__Azotobacter at 0x379efe9d0>,
#  <Reaction IMPD__Azotobacter at 0x379efeac0>,
#  <Reaction ECOAH4__Azotobacter at 0x379efec10>,
#  <Reaction GLUTRS__Azotobacter at 0x379f0a310>,
#  <Reaction TMPPP__Azotobacter at 0x379f29e50>,
#  <Reaction NDPK5__Azotobacter at 0x379f50f40>,
#  <Reaction DHORTS__Azotobacter at 0x37a2c78b0>,
#  <Reaction OMPDC__Azotobacter at 0x379f4c910>,
#  <Reaction CS__Azotobacter at 0x37a21d820>,
#  <Reaction ICDHyr__Azotobacter at 0x37a3a7a90>,
#  <Reaction ACALD__Azotobacter at 0x37a72ac10>,
#  <Reaction ACS__Azotobacter at 0x37a750b80>,
#  <Reaction PPA__Azotobacter at 0x37a3a1580>,
#  <Reaction PPCK__Azotobacter at 0x37a7564c0>,
#  <Reaction ALAR__Azotobacter at 0x37a7cbac0>,
#  <Reaction ALATA_L__Azotobacter at 0x37ac351f0>,
#  <Reaction XYLK__Azotobacter at 0x37afd58e0>,
#  <Reaction GLYK__Azotobacter at 0x37af7fe50>,
#  <Reaction ASPTA__Azotobacter at 0x37b33feb0>,
#  <Reaction FBP__Azotobacter at 0x37b97a280>,
#  <Reaction PYK__Azotobacter at 0x37b9ead90>,
#  <Reaction A5PISO__Azotobacter at 0x37ba66d90>,
#  <Reaction EX_metsox_S__L_e__Azotobacter at 0x37a77fb50>,
#  <Reaction IPPMIb__Azotobacter at 0x37ba66c10>,
#  <Reaction ACHBS__Azotobacter at 0x37bd467f0>,
#  <Reaction ACLS__Azotobacter at 0x37be41e20>,
#  <Reaction PSCVT__Azotobacter at 0x37c112970>,
#  <Reaction ANS__Azotobacter at 0x37c074fa0>,
#  <Reaction ANPRT__Azotobacter at 0x37c9536d0>,
#  <Reaction CHORM__Azotobacter at 0x37cc5ea00>,
#  <Reaction CHORS__Azotobacter at 0x37c843fa0>,
#  <Reaction IGPS__Azotobacter at 0x37c94f370>,
#  <Reaction EX_crn_e__Azotobacter at 0x37ccbb970>,
#  <Reaction EX_fe3_e__Azotobacter at 0x37cff8ac0>,
#  <Reaction EX_glcn_e__Azotobacter at 0x37cfaf940>,
#  <Reaction EX_gln__L_e__Azotobacter at 0x37d020c40>,
#  <Reaction EX_glyc_e__Azotobacter at 0x37d025b80>,
#  <Reaction EX_man_e__Azotobacter at 0x37d0498e0>,
#  <Reaction EX_mn2_e__Azotobacter at 0x37d049bb0>,
#  <Reaction EX_rib__D_e__Azotobacter at 0x37d04f9d0>,
#  <Reaction EX_sbt__D_e__Azotobacter at 0x37d0640d0>,
#  <Reaction ECOAH6__Azotobacter at 0x37d0723d0>,
#  <Reaction ENO__Azotobacter at 0x37d072c10>,
#  <Reaction PPS__Azotobacter at 0x37d40e040>,
#  <Reaction PGI__Azotobacter at 0x37d07a250>,
#  <Reaction PGK__Azotobacter at 0x37d82ab50>,
#  <Reaction EDA__Azotobacter at 0x37d39a160>,
#  <Reaction RPE__Azotobacter at 0x37d85ed90>,
#  <Reaction TALA__Azotobacter at 0x37d887e80>,
#  <Reaction TKT1__Azotobacter at 0x37d8b0430>,
#  <Reaction ALCD2x__Azotobacter at 0x37d891460>,
#  <Reaction ALDD2y__Azotobacter at 0x37dfa84c0>,
#  <Reaction EX_ura_e__Azotobacter at 0x37e63fdc0>,
#  <Reaction EX_xan_e__Azotobacter at 0x37dfa3d60>,
#  <Reaction FMNAT__Azotobacter at 0x37e314490>,
#  <Reaction NADDP__Azotobacter at 0x37e6508e0>,
#  <Reaction NMNAT__Azotobacter at 0x37e9b2310>,
#  <Reaction HMPK1__Azotobacter at 0x37e650c10>,
#  <Reaction NDPK6__Azotobacter at 0x37e8be190>,
#  <Reaction NDPK8__Azotobacter at 0x37ea06520>,
#  <Reaction PTRCTA__Azotobacter at 0x37e9d6fd0>,
#  <Reaction CYSDS__Azotobacter at 0x37ed94970>,
#  <Reaction EX_co2_e__Azotobacter at 0x37edc4e50>,
#  <Reaction PMDPHT__Azotobacter at 0x37f1632e0>,
#  <Reaction ILETA__Azotobacter at 0x37f47aa30>,
#  <Reaction VALTA__Azotobacter at 0x37f409790>,
#  ...]

# %%
community.metabolites
# Out:
# [<Metabolite gln__L_e__Synechococcus at 0x34fe313d0>,
#  <Metabolite hco3_e__Synechococcus at 0x34fe314f0>,
#  <Metabolite mn2_e__Synechococcus at 0x34fe315e0>,
#  <Metabolite arg__L_e__Synechococcus at 0x34fe316d0>,
#  <Metabolite ade_c__Synechococcus at 0x34fe317c0>,
#  <Metabolite amp_c__Synechococcus at 0x34fe317f0>,
#  <Metabolite ppi_c__Synechococcus at 0x34fe31820>,
#  <Metabolite prpp_c__Synechococcus at 0x34fe31850>,
#  <Metabolite o2_c__Synechococcus at 0x34fe31970>,
#  <Metabolite o2_cx__Synechococcus at 0x34fe318e0>,
#  <Metabolite 2a3pp_c__Synechococcus at 0x34fe319d0>,
#  <Metabolite 3a2oxpp_c__Synechococcus at 0x34fe31a30>,
#  <Metabolite co2_c__Synechococcus at 0x34fe31b20>,
#  <Metabolite h_c__Synechococcus at 0x34fe31af0>,
#  <Metabolite ahdt_c__Synechococcus at 0x34fe31ca0>,
#  <Metabolite dhpmp_c__Synechococcus at 0x34fe31cd0>,
#  <Metabolite h2o_c__Synechococcus at 0x34fe31d30>,
#  <Metabolite cbm_c__Synechococcus at 0x34fe31e80>,
#  <Metabolite nh4_c__Synechococcus at 0x34fe31f10>,
#  <Metabolite bm_pigm_c__Synechococcus at 0x34fe3e190>,
#  <Metabolite calxan_c__Synechococcus at 0x34fe3e220>,
#  <Metabolite caro_c__Synechococcus at 0x34fe3e2e0>,
#  <Metabolite cholphya_c__Synechococcus at 0x34fe3e670>,
#  <Metabolite hpdcn_c__Synechococcus at 0x34fe3e430>,
#  <Metabolite nstxan_c__Synechococcus at 0x34fe3e490>,
#  <Metabolite phycy_c__Synechococcus at 0x34fe3e970>,
#  <Metabolite zeax_c__Synechococcus at 0x34fe440a0>,
#  <Metabolite h2o_u__Synechococcus at 0x34fe445b0>,
#  <Metabolite adp_c__Synechococcus at 0x34fe6f940>,
#  <Metabolite atp_c__Synechococcus at 0x34fe6f1c0>,
#  <Metabolite dtdp_c__Synechococcus at 0x34fe78d90>,
#  <Metabolite dtmp_c__Synechococcus at 0x34fe783a0>,
#  <Metabolite bm_carbs_c__Synechococcus at 0x34fe78e50>,
#  <Metabolite bm_cofactors_c__Synechococcus at 0x34fe78d00>,
#  <Metabolite bm_cw_c__Synechococcus at 0x34fe78dc0>,
#  <Metabolite bm_dna_c__Synechococcus at 0x34fe88040>,
#  <Metabolite bm_memlip_c__Synechococcus at 0x34fe88100>,
#  <Metabolite bm_pro_c__Synechococcus at 0x34fe880d0>,
#  <Metabolite bm_rna_c__Synechococcus at 0x34fe88130>,
#  <Metabolite pi_c__Synechococcus at 0x34fe88220>,
#  <Metabolite akg_c__Synechococcus at 0x34fe88310>,
#  <Metabolite glu5sa_c__Synechococcus at 0x34fe883a0>,
#  <Metabolite glu__L_c__Synechococcus at 0x34fe883d0>,
#  <Metabolite orn_c__Synechococcus at 0x34fe88430>,
#  <Metabolite ACP_c__Synechococcus at 0x34fe88520>,
#  <Metabolite acACP_c__Synechococcus at 0x34fe88850>,
#  <Metabolite accoa_c__Synechococcus at 0x34fe88820>,
#  <Metabolite coa_c__Synechococcus at 0x34fe888e0>,
#  <Metabolite 5drib_c__Synechococcus at 0x34fe8edc0>,
#  <Metabolite dad_5_c__Synechococcus at 0x34fe8ec70>,
#  <Metabolite 3hpalmACP_c__Synechococcus at 0x34feca490>,
#  <Metabolite tpalm2eACP_c__Synechococcus at 0x34feca5e0>,
#  <Metabolite cdp_c__Synechococcus at 0x34fecaee0>,
#  <Metabolite dcdp_c__Synechococcus at 0x34fecaa00>,
#  <Metabolite trdox_c__Synechococcus at 0x34feca8b0>,
#  <Metabolite trdrd_c__Synechococcus at 0x34feca9a0>,
#  <Metabolite h_e__Synechococcus at 0x34fed2c40>,
#  <Metabolite h_p__Synechococcus at 0x34fed2910>,
#  <Metabolite glu5p_c__Synechococcus at 0x34ff09f10>,
#  <Metabolite nadp_c__Synechococcus at 0x34ff11250>,
#  <Metabolite nadph_c__Synechococcus at 0x34ff11940>,
#  <Metabolite histd_c__Synechococcus at 0x34ff46af0>,
#  <Metabolite histda_c__Synechococcus at 0x34ff46f40>,
#  <Metabolite nad_c__Synechococcus at 0x34ff46a60>,
#  <Metabolite nadh_c__Synechococcus at 0x34ff46a00>,
#  <Metabolite 3ig3p_c__Synechococcus at 0x34ff4eb50>,
#  <Metabolite g3p_c__Synechococcus at 0x34ff4e280>,
#  <Metabolite indole_c__Synechococcus at 0x34ff4e970>,
#  <Metabolite dialurate_c__Synechococcus at 0x34ffc6ee0>,
#  <Metabolite dmbzid_c__Synechococcus at 0x34ffbd970>,
#  <Metabolite e4p_c__Synechococcus at 0x34ffbdc70>,
#  <Metabolite fmnh2_c__Synechococcus at 0x34ff8be20>,
#  <Metabolite hisp_c__Synechococcus at 0x35051cf70>,
#  <Metabolite imacp_c__Synechococcus at 0x35051ce20>,
#  <Metabolite lycop_c__Synechococcus at 0x3504be250>,
#  <Metabolite neuspn_c__Synechococcus at 0x35051cd90>,
#  <Metabolite ptrc_c__Synechococcus at 0x3508b77f0>,
#  <Metabolite 6pgc_c__Synechococcus at 0x34ff829a0>,
#  <Metabolite ru5p__D_c__Synechococcus at 0x3508b75e0>,
#  <Metabolite Ncbmpts_c__Synechococcus at 0x350bf6790>,
#  <Metabolite u23ga2_c__Synechococcus at 0x350c4f790>,
#  <Metabolite u3hga2_c__Synechococcus at 0x350bf6e80>,
#  <Metabolite biliverd_c__Synechococcus at 0x350f8f7f0>,
#  <Metabolite co_c__Synechococcus at 0x350f8f550>,
#  <Metabolite fdxox_c__Synechococcus at 0x350556c10>,
#  <Metabolite fdxrd_c__Synechococcus at 0x3505569a0>,
#  <Metabolite fe2_c__Synechococcus at 0x350fd11c0>,
#  <Metabolite pheme_c__Synechococcus at 0x350f60910>,
#  <Metabolite 13dpg_c__Synechococcus at 0x350faca00>,
#  <Metabolite 3pg_c__Synechococcus at 0x350fac640>,
#  <Metabolite imp_c__Synechococcus at 0x350fd6970>,
#  <Metabolite xmp_c__Synechococcus at 0x350fd6580>,
#  <Metabolite chlld_c__Synechococcus at 0x350ffe700>,
#  <Metabolite pchlld_exc_c__Synechococcus at 0x350ffea90>,
#  <Metabolite 4hbz_c__Synechococcus at 0x351028460>,
#  <Metabolite chor_c__Synechococcus at 0x351049d60>,
#  <Metabolite pyr_c__Synechococcus at 0x350fac760>,
#  <Metabolite gcald_c__Synechococcus at 0x351052580>,
#  <Metabolite glyclt_c__Synechococcus at 0x351052160>,
#  <Metabolite 2m6sbenzq_c__Synechococcus at 0x35107c4c0>,
#  <Metabolite ahcys_c__Synechococcus at 0x35107c0a0>,
#  <Metabolite amet_c__Synechococcus at 0x350fecdf0>,
#  <Metabolite pqh2_c__Synechococcus at 0x351072ca0>,
#  <Metabolite ocdcaACP_c__Synechococcus at 0x3510a44c0>,
#  <Metabolite octe9ACP_c__Synechococcus at 0x3510a4b50>,
#  <Metabolite fum_c__Synechococcus at 0x3510da430>,
#  <Metabolite mal__L_c__Synechococcus at 0x3510da370>,
#  <Metabolite 2mahmp_c__Synechococcus at 0x3510a4250>,
#  <Metabolite cthzp_c__Synechococcus at 0x3510a4340>,
#  <Metabolite thmmp_c__Synechococcus at 0x351117220>,
#  <Metabolite 3mob_c__Synechococcus at 0x35118c3a0>,
#  <Metabolite ala__L_c__Synechococcus at 0x3511172b0>,
#  <Metabolite val__L_c__Synechococcus at 0x351152250>,
#  <Metabolite dadp_c__Synechococcus at 0x3511ca340>,
#  <Metabolite f6p_c__Synechococcus at 0x3511fce20>,
#  <Metabolite s7p_c__Synechococcus at 0x3511fceb0>,
#  <Metabolite gly_c__Synechococcus at 0x351235e50>,
#  <Metabolite mlthf_c__Synechococcus at 0x351235df0>,
#  <Metabolite thf_c__Synechococcus at 0x3511ca040>,
#  <Metabolite cit_c__Synechococcus at 0x3512abe20>,
#  <Metabolite icit_c__Synechococcus at 0x3512abd60>,
#  <Metabolite dctp_c__Synechococcus at 0x351240f10>,
#  <Metabolite for_c__Synechococcus at 0x3512b71f0>,
#  <Metabolite gtp_c__Synechococcus at 0x3512ab190>,
#  <Metabolite 5caiz_c__Synechococcus at 0x3513673a0>,
#  <Metabolite air_c__Synechococcus at 0x3513672b0>,
#  <Metabolite hco3_c__Synechococcus at 0x35127a0a0>,
#  <Metabolite 2cpr5p_c__Synechococcus at 0x351725310>,
#  <Metabolite 5mdr1p_c__Synechococcus at 0x3517d2190>,
#  <Metabolite 5mta_c__Synechococcus at 0x351725220>,
#  <Metabolite hemeA_c__Synechococcus at 0x3517d7370>,
#  <Metabolite hemeO_c__Synechococcus at 0x3517d76a0>,
#  <Metabolite dhor__S_c__Synechococcus at 0x351825130>,
#  <Metabolite orot_c__Synechococcus at 0x35181fdf0>,
#  <Metabolite pq_um__Synechococcus at 0x351725b50>,
#  <Metabolite pqh2_um__Synechococcus at 0x3517250a0>,
#  <Metabolite 10fthf_c__Synechococcus at 0x351850340>,
#  <Metabolite methf_c__Synechococcus at 0x3518500d0>,
#  <Metabolite 3nphb_c__Synechococcus at 0x3518790d0>,
#  <Metabolite npdp_c__Synechococcus at 0x3518790a0>,
#  <Metabolite gcarote_c__Synechococcus at 0x35189ce80>,
#  <Metabolite co2dam_c__Synechococcus at 0x3518c7df0>,
#  <Metabolite cobalt2_c__Synechococcus at 0x3518468e0>,
#  <Metabolite hgbam_c__Synechococcus at 0x35189cd60>,
#  <Metabolite aspsa_c__Synechococcus at 0x351903580>,
#  <Metabolite hom__L_c__Synechococcus at 0x3519030a0>,
#  <Metabolite ser__L_c__Synechococcus at 0x351936d30>,
#  <Metabolite trp__L_c__Synechococcus at 0x351936910>,
#  <Metabolite his__L_c__Synechococcus at 0x3519a9a60>,
#  <Metabolite cpppg3_c__Synechococcus at 0x3519f8670>,
#  <Metabolite uppg3_c__Synechococcus at 0x3518fbd30>,
#  <Metabolite fgam_c__Synechococcus at 0x351e009a0>,
#  <Metabolite gar_c__Synechococcus at 0x351e00fd0>,
#  <Metabolite 4hthdp_c__Synechococcus at 0x351e4ec40>,
#  <Metabolite thdp_c__Synechococcus at 0x351e4e8e0>,
#  <Metabolite udpg_c__Synechococcus at 0x3521a0820>,
#  <Metabolite udpgal_c__Synechococcus at 0x3521a06a0>,
#  <Metabolite 14glucan_c__Synechococcus at 0x3521c1520>,
#  <Metabolite adpglc_c__Synechococcus at 0x3521e6310>,
#  <Metabolite amylose_c__Synechococcus at 0x35193ebb0>,
#  <Metabolite aicar_c__Synechococcus at 0x3521ec880>,
#  <Metabolite fprica_c__Synechococcus at 0x3521ec460>,
#  <Metabolite asp__L_c__Synechococcus at 0x3522147c0>,
#  <Metabolite oaa_c__Synechococcus at 0x3522143a0>,
#  <Metabolite gthrd_c__Synechococcus at 0x35223e670>,
#  <Metabolite lac__D_c__Synechococcus at 0x35223e550>,
#  <Metabolite lgt__S_c__Synechococcus at 0x351970100>,
#  <Metabolite pram_c__Synechococcus at 0x35226d4f0>,
#  <Metabolite so3_c__Synechococcus at 0x352210250>,
#  <Metabolite udpsq_c__Synechococcus at 0x352267670>,
#  <Metabolite ac_c__Synechococcus at 0x3522917c0>,
#  <Metabolite actp_c__Synechococcus at 0x3522914f0>,
#  <Metabolite frdp_c__Synechococcus at 0x3522f1af0>,
#  <Metabolite ipdp_c__Synechococcus at 0x3522f13d0>,
#  <Metabolite udcpdp_c__Synechococcus at 0x3522672e0>,
#  <Metabolite gdp_c__Synechococcus at 0x352717bb0>,
#  <Metabolite gmp_c__Synechococcus at 0x352717850>,
#  <Metabolite skm5p_c__Synechococcus at 0x352731af0>,
#  <Metabolite skm_c__Synechococcus at 0x3527316d0>,
#  <Metabolite oxa_c__Synechococcus at 0x35275c9a0>,
#  <Metabolite acgam1p_c__Synechococcus at 0x352761f10>,
#  <Metabolite gam1p_c__Synechococcus at 0x3526270d0>,
#  <Metabolite 3hhexACP_c__Synechococcus at 0x3527ad820>,
#  <Metabolite thex2eACP_c__Synechococcus at 0x35278a130>,
#  <Metabolite g6p_c__Synechococcus at 0x3527d6670>,
#  <Metabolite actACP_c__Synechococcus at 0x3527dd6a0>,
#  <Metabolite malACP_c__Synechococcus at 0x3522ba0d0>,
#  <Metabolite ohpb_c__Synechococcus at 0x3528295b0>,
#  <Metabolite phthr_c__Synechococcus at 0x352806130>,
#  <Metabolite o2_u__Synechococcus at 0x35275c880>,
#  <Metabolite o2_p__Synechococcus at 0x3528984c0>,
#  <Metabolite h2o_e__Synechococcus at 0x3528d2070>,
#  <Metabolite h2o_p__Synechococcus at 0x3528d2400>,
#  <Metabolite mg2_e__Synechococcus at 0x3528d9790>,
#  <Metabolite 3hoctACP_c__Synechococcus at 0x35290d340>,
#  <Metabolite toct2eACP_c__Synechococcus at 0x35290d400>,
#  <Metabolite 3opalmACP_c__Synechococcus at 0x35290d5b0>,
#  <Metabolite ncam_c__Synechococcus at 0x3529154f0>,
#  <Metabolite nmn_c__Synechococcus at 0x3529151c0>,
#  <Metabolite g1p_c__Synechococcus at 0x352940e20>,
#  <Metabolite utp_c__Synechococcus at 0x35290d550>,
#  <Metabolite phyto_c__Synechococcus at 0x35290d790>,
#  <Metabolite prephytedp_c__Synechococcus at 0x352948670>,
#  <Metabolite eig3p_c__Synechococcus at 0x352994670>,
#  <Metabolite orot5p_c__Synechococcus at 0x3529e26a0>,
#  <Metabolite ump_c__Synechococcus at 0x3529949a0>,
#  <Metabolite dutp_c__Synechococcus at 0x352a3d2b0>,
#  <Metabolite gln__L_c__Synechococcus at 0x352a423d0>,
#  <Metabolite dnad_c__Synechococcus at 0x352a774c0>,
#  <Metabolite glu1sa_c__Synechococcus at 0x352ab13d0>,
#  <Metabolite glutrna_c__Synechococcus at 0x352a0a2b0>,
#  <Metabolite trnaglu_c__Synechococcus at 0x352948910>,
#  <Metabolite dtdpglu_c__Synechococcus at 0x352b2b220>,
#  <Metabolite dttp_c__Synechococcus at 0x352948160>,
#  <Metabolite glu__D_c__Synechococcus at 0x352b5be50>,
#  <Metabolite uama_c__Synechococcus at 0x352b5bdf0>,
#  <Metabolite uamag_c__Synechococcus at 0x352aee550>,
#  <Metabolite suc6p_c__Synechococcus at 0x352aeef40>,
#  <Metabolite udp_c__Synechococcus at 0x352b94c70>,
#  <Metabolite 4abz_c__Synechococcus at 0x352bd0d60>,
#  <Metabolite 4adcho_c__Synechococcus at 0x352bd09d0>,
#  <Metabolite cmp_c__Synechococcus at 0x352c0abe0>,
#  <Metabolite 26dap__M_c__Synechococcus at 0x352c171c0>,
#  <Metabolite lys__L_c__Synechococcus at 0x352c0ac10>,
#  <Metabolite o2s_c__Synechococcus at 0x352c81a90>,
#  <Metabolite p700_exc_um__Synechococcus at 0x352c4f3a0>,
#  <Metabolite p700_um__Synechococcus at 0x352b94d60>,
#  <Metabolite pcox_u__Synechococcus at 0x352b94d00>,
#  <Metabolite pcrd_u__Synechococcus at 0x352cee1f0>,
#  <Metabolite pre5_c__Synechococcus at 0x352d64040>,
#  <Metabolite pre6a_c__Synechococcus at 0x352d642b0>,
#  <Metabolite cobalt2_p__Synechococcus at 0x352cb32b0>,
#  <Metabolite s17bp_c__Synechococcus at 0x352cf6bb0>,
#  <Metabolite phom_c__Synechococcus at 0x352d4ca30>,
#  <Metabolite thr__L_c__Synechococcus at 0x352d318e0>,
#  <Metabolite nac_c__Synechococcus at 0x352fc63a0>,
#  <Metabolite nicrnt_c__Synechococcus at 0x35328ff40>,
#  <Metabolite 2ahhmd_c__Synechococcus at 0x3532c1850>,
#  <Metabolite dhpt_c__Synechococcus at 0x35328f910>,
#  <Metabolite 1pyr5c_c__Synechococcus at 0x35362e310>,
#  <Metabolite pro__L_c__Synechococcus at 0x35362e880>,
#  <Metabolite ichor_c__Synechococcus at 0x352d31820>,
#  <Metabolite 3omrsACP_c__Synechococcus at 0x353945340>,
#  <Metabolite ddcaACP_c__Synechococcus at 0x352d31b50>,
#  <Metabolite pppi_c__Synechococcus at 0x3539e1220>,
#  <Metabolite h2mb4p_c__Synechococcus at 0x353a5d400>,
#  <Metabolite glx_c__Synechococcus at 0x3539667c0>,
#  <Metabolite hexACP_c__Synechococcus at 0x353ddc160>,
#  <Metabolite zn2_c__Synechococcus at 0x353e476d0>,
#  <Metabolite zn2_p__Synechococcus at 0x353966070>,
#  <Metabolite uaccg_c__Synechococcus at 0x353e96e50>,
#  <Metabolite uamr_c__Synechococcus at 0x353ee4670>,
#  <Metabolite 23dhmb_c__Synechococcus at 0x353e9c2e0>,
#  <Metabolite 3c3hmp_c__Synechococcus at 0x353ec6d90>,
#  <Metabolite anth_c__Synechococcus at 0x353ee9d90>,
#  <Metabolite sbzcoa_c__Synechococcus at 0x35434ea90>,
#  <Metabolite sucbz_c__Synechococcus at 0x35434e850>,
#  <Metabolite dcamp_c__Synechococcus at 0x35434e100>,
#  <Metabolite 4per_c__Synechococcus at 0x3543b5b20>,
#  <Metabolite 5aop_c__Synechococcus at 0x354363ca0>,
#  <Metabolite ppbng_c__Synechococcus at 0x353ebfbe0>,
#  <Metabolite adocbl_c__Synechococcus at 0x35475ea60>,
#  <Metabolite agdpcbi_c__Synechococcus at 0x35475ea00>,
#  <Metabolite rdmbzi_c__Synechococcus at 0x353ebfdc0>,
#  <Metabolite thrp_c__Synechococcus at 0x3547aa670>,
#  <Metabolite pep_c__Synechococcus at 0x354b5e490>,
#  <Metabolite 5aprbu_c__Synechococcus at 0x354b5a070>,
#  <Metabolite 5apru_c__Synechococcus at 0x354b5adf0>,
#  <Metabolite phytfl_c__Synechococcus at 0x353ebfd30>,
#  <Metabolite zcarote_c__Synechococcus at 0x354a4c130>,
#  <Metabolite o2_e__Synechococcus at 0x354ba7f10>,
#  <Metabolite ala__D_c__Synechococcus at 0x354f20580>,
#  <Metabolite alaala_c__Synechococcus at 0x354f57190>,
#  <Metabolite adcobhex_c__Synechococcus at 0x354f57580>,
#  <Metabolite adocbip_c__Synechococcus at 0x354f57520>,
#  <Metabolite applp_c__Synechococcus at 0x354f57250>,
#  <Metabolite gam6p_c__Synechococcus at 0x354ef1490>,
#  <Metabolite dhnpt_c__Synechococcus at 0x354f71a90>,
#  <Metabolite agm_c__Synechococcus at 0x354f9b550>,
#  <Metabolite lipidAds2_c__Synechococcus at 0x354fed430>,
#  <Metabolite lipidX2_c__Synechococcus at 0x354fc3520>,
#  <Metabolite glyc__R_c__Synechococcus at 0x3550153d0>,
#  <Metabolite 2dhp_c__Synechococcus at 0x355015370>,
#  <Metabolite pant__R_c__Synechococcus at 0x354fc34c0>,
#  <Metabolite ptrc_e__Synechococcus at 0x3550405e0>,
#  <Metabolite tddec2eACP_c__Synechococcus at 0x35506d340>,
#  <Metabolite gdpmann_c__Synechococcus at 0x3550cf3a0>,
#  <Metabolite man1p_c__Synechococcus at 0x35509b430>,
#  <Metabolite xu5p__D_c__Synechococcus at 0x355118400>,
#  <Metabolite pser__L_c__Synechococcus at 0x3550d83a0>,
#  <Metabolite fru_c__Synechococcus at 0x35514e070>,
#  <Metabolite 4ppan_c__Synechococcus at 0x3551b36d0>,
#  <Metabolite 4ppcys_c__Synechococcus at 0x355108f70>,
#  <Metabolite ctp_c__Synechococcus at 0x35509b970>,
#  <Metabolite cys__L_c__Synechococcus at 0x35509b190>,
#  <Metabolite 3psme_c__Synechococcus at 0x35562aa30>,
#  <Metabolite pq_cm__Synechococcus at 0x35563b460>,
#  <Metabolite pqh2_cm__Synechococcus at 0x35562a130>,
#  <Metabolite pan4p_c__Synechococcus at 0x35566a280>,
#  <Metabolite hpyr_c__Synechococcus at 0x355665310>,
#  <Metabolite ametam_c__Synechococcus at 0x355accd60>,
#  <Metabolite pre3a_c__Synechococcus at 0x355ae7820>,
#  <Metabolite pre3b_c__Synechococcus at 0x355b0b7c0>,
#  <Metabolite h2o2_c__Synechococcus at 0x355b54d00>,
#  <Metabolite ppp9_c__Synechococcus at 0x355acc520>,
#  <Metabolite pppg9_c__Synechococcus at 0x355b0bb50>,
#  <Metabolite datp_c__Synechococcus at 0x355b8b7f0>,
#  <Metabolite dgtp_c__Synechococcus at 0x355ae27f0>,
#  <Metabolite dmpp_c__Synechococcus at 0x355e0a0a0>,
#  <Metabolite grdp_c__Synechococcus at 0x355b345e0>,
#  <Metabolite dna5mtc_c__Synechococcus at 0x355ea7a00>,
#  <Metabolite dna_c__Synechococcus at 0x355ea7d30>,
#  <Metabolite dhap_c__Synechococcus at 0x355f6aac0>,
#  <Metabolite glyc3p_c__Synechococcus at 0x355f6a7c0>,
#  <Metabolite colipacy_e__Synechococcus at 0x355fdc2b0>,
#  <Metabolite murein5p5p5p_p__Synechococcus at 0x355fdc190>,
#  <Metabolite ggdp_c__Synechococcus at 0x356332f40>,
#  <Metabolite rb15bp_c__Synechococcus at 0x35635fdc0>,
#  <Metabolite rb15bp_cx__Synechococcus at 0x356250550>,
#  <Metabolite inost_c__Synechococcus at 0x3563632e0>,
#  <Metabolite mi3p__D_c__Synechococcus at 0x356363490>,
#  <Metabolite fdp_c__Synechococcus at 0x35638f0a0>,
#  <Metabolite 5prdmbz_c__Synechococcus at 0x3563b78b0>,
#  <Metabolite 4hpro_LT_c__Synechococcus at 0x3563f82e0>,
#  <Metabolite succ_c__Synechococcus at 0x3563dac40>,
#  <Metabolite 4pasp_c__Synechococcus at 0x356405e50>,
#  <Metabolite acser_c__Synechococcus at 0x35640b280>,
#  <Metabolite h2s_c__Synechococcus at 0x3563e3250>,
#  <Metabolite acg5sa_c__Synechococcus at 0x356439070>,
#  <Metabolite acorn_c__Synechococcus at 0x356439040>,
#  <Metabolite 3hoctaACP_c__Synechococcus at 0x35645d460>,
#  <Metabolite toctd2eACP_c__Synechococcus at 0x35645d0a0>,
#  <Metabolite acald_c__Synechococcus at 0x356458df0>,
#  <Metabolite 3ooctACP_c__Synechococcus at 0x35690c850>,
#  <Metabolite cbp_c__Synechococcus at 0x3564c8d60>,
#  <Metabolite 2me4p_c__Synechococcus at 0x35699a250>,
#  <Metabolite 4c2me_c__Synechococcus at 0x35699a6a0>,
#  <Metabolite pdx5p_c__Synechococcus at 0x3569c30d0>,
#  <Metabolite pydx5p_c__Synechococcus at 0x3569c30a0>,
#  <Metabolite 23dhmp_c__Synechococcus at 0x356a46280>,
#  <Metabolite 3mop_c__Synechococcus at 0x356a468e0>,
#  <Metabolite dhf_c__Synechococcus at 0x356e37490>,
#  <Metabolite 3php_c__Synechococcus at 0x356c7e4f0>,
#  <Metabolite spmd_c__Synechococcus at 0x356e4d820>,
#  <Metabolite spmd_p__Synechococcus at 0x356e37310>,
#  <Metabolite dad_2_c__Synechococcus at 0x356ea00a0>,
#  <Metabolite damp_c__Synechococcus at 0x356e7d550>,
#  <Metabolite prbamp_c__Synechococcus at 0x356971790>,
#  <Metabolite prbatp_c__Synechococcus at 0x356971550>,
#  <Metabolite asn__L_c__Synechococcus at 0x356ef2250>,
#  <Metabolite fpram_c__Synechococcus at 0x356f71eb0>,
#  <Metabolite prfp_c__Synechococcus at 0x356f7c220>,
#  <Metabolite 4ampm_c__Synechococcus at 0x356facd00>,
#  <Metabolite met__L_c__Synechococcus at 0x356eca2b0>,
#  <Metabolite cdpglc_c__Synechococcus at 0x35705b0a0>,
#  <Metabolite 2sephchc_c__Synechococcus at 0x3573e7250>,
#  <Metabolite ca2_c__Synechococcus at 0x3574b59d0>,
#  <Metabolite ca2_p__Synechococcus at 0x3573e7070>,
#  <Metabolite acglu_c__Synechococcus at 0x3574de5e0>,
#  <Metabolite 2shchc_c__Synechococcus at 0x3576097c0>,
#  <Metabolite u3aga2_c__Synechococcus at 0x3576313d0>,
#  <Metabolite dhna_c__Synechococcus at 0x3576595b0>,
#  <Metabolite dmtphllqne_c__Synechococcus at 0x3574de250>,
#  <Metabolite phdp_c__Synechococcus at 0x35748c550>,
#  <Metabolite iasp_c__Synechococcus at 0x3576e03d0>,
#  <Metabolite hgbyr_c__Synechococcus at 0x35748c5b0>,
#  <Metabolite ala_B_c__Synechococcus at 0x3576ad130>,
#  <Metabolite phpyr_c__Synechococcus at 0x357baea60>,
#  <Metabolite pphn_c__Synechococcus at 0x3576ade80>,
#  <Metabolite dxyl5p_c__Synechococcus at 0x3576e9fd0>,
#  <Metabolite 3pg_cx__Synechococcus at 0x357acb190>,
#  <Metabolite 4h2oglt_c__Synechococcus at 0x357c48e50>,
#  <Metabolite pap_c__Synechococcus at 0x357c48fa0>,
#  <Metabolite paps_c__Synechococcus at 0x357c70c70>,
#  <Metabolite aps_c__Synechococcus at 0x357c9ac40>,
#  <Metabolite so4_c__Synechococcus at 0x357c9aaf0>,
#  <Metabolite 5mthf_c__Synechococcus at 0x357cc4a60>,
#  <Metabolite btamp_c__Synechococcus at 0x357cc4b20>,
#  <Metabolite fad_c__Synechococcus at 0x357c70ee0>,
#  <Metabolite fe3_c__Synechococcus at 0x357c70940>,
#  <Metabolite gthbpt_c__Synechococcus at 0x357d25190>,
#  <Metabolite k_c__Synechococcus at 0x357cde610>,
#  <Metabolite lipopb_c__Synechococcus at 0x357cf3760>,
#  <Metabolite na1_c__Synechococcus at 0x357cf3a30>,
#  <Metabolite phllqne_c__Synechococcus at 0x357cf3ca0>,
#  <Metabolite sheme_c__Synechococcus at 0x357cfc1c0>,
#  <Metabolite thmpp_c__Synechococcus at 0x357d2e8b0>,
#  <Metabolite dpcoa_c__Synechococcus at 0x357d2eb80>,
#  <Metabolite nh4_p__Synechococcus at 0x357d35d00>,
#  <Metabolite h2_c__Synechococcus at 0x357d68b20>,
#  <Metabolite pre4_c__Synechococcus at 0x357d2ebe0>,
#  <Metabolite pchlld_c__Synechococcus at 0x357d71d90>,
#  <Metabolite arg__L_c__Synechococcus at 0x357dac8e0>,
#  <Metabolite argsuc_c__Synechococcus at 0x357e1d0a0>,
#  <Metabolite 4r5au_c__Synechococcus at 0x357d71730>,
#  <Metabolite arg__L_p__Synechococcus at 0x357d71c40>,
#  <Metabolite 3hmrsACP_c__Synechococcus at 0x358604bb0>,
#  <Metabolite tmrs2eACP_c__Synechococcus at 0x358604580>,
#  <Metabolite 5g2oxpt_c__Synechococcus at 0x3585de190>,
#  <Metabolite 26dap_LL_c__Synechococcus at 0x35862c640>,
#  <Metabolite bcryptox_c__Synechococcus at 0x3586a7af0>,
#  <Metabolite 2ahhmp_c__Synechococcus at 0x3585de0d0>,
#  <Metabolite pnto__R_c__Synechococcus at 0x358a36eb0>,
#  <Metabolite adn_c__Synechococcus at 0x358a5afa0>,
#  <Metabolite hcys__L_c__Synechococcus at 0x358a13c70>,
#  <Metabolite 6pgl_c__Synechococcus at 0x358aac490>,
#  <Metabolite 25dhpp_c__Synechococcus at 0x358adb700>,
#  <Metabolite glycogen_c__Synechococcus at 0x358afea00>,
#  <Metabolite db4p_c__Synechococcus at 0x358b276d0>,
#  <Metabolite dmlz_c__Synechococcus at 0x358be5af0>,
#  <Metabolite hmppp9_c__Synechococcus at 0x359039580>,
#  <Metabolite omppp9_c__Synechococcus at 0x358a88a90>,
#  <Metabolite palmACP_c__Synechococcus at 0x358b506a0>,
#  <Metabolite cbasp_c__Synechococcus at 0x3590a6b50>,
#  <Metabolite 3hmop_c__Synechococcus at 0x359054850>,
#  <Metabolite 5aizc_c__Synechococcus at 0x3591bc2b0>,
#  <Metabolite ribflv_c__Synechococcus at 0x35925be50>,
#  <Metabolite citac_c__Synechococcus at 0x3591e6f40>,
#  <Metabolite r3mmal_c__Synechococcus at 0x359122850>,
#  <Metabolite mn2_c__Synechococcus at 0x3593bfb20>,
#  <Metabolite mn2_p__Synechococcus at 0x359376310>,
#  <Metabolite acg5p_c__Synechococcus at 0x359bc7c70>,
#  <Metabolite 3c2hmp_c__Synechococcus at 0x359baa070>,
#  <Metabolite 3c4mop_c__Synechococcus at 0x359bc7fd0>,
#  <Metabolite 2p4c2me_c__Synechococcus at 0x359ee4dc0>,
#  <Metabolite dvpchlda_c__Synechococcus at 0x359bc7d90>,
#  <Metabolite hco3_p__Synechococcus at 0x35a23b850>,
#  <Metabolite na1_p__Synechococcus at 0x35a23b0a0>,
#  <Metabolite man6p_c__Synechococcus at 0x35a2aa310>,
#  <Metabolite mppp9_c__Synechococcus at 0x35a2fce50>,
#  <Metabolite mppp9me_c__Synechococcus at 0x359bc7970>,
#  <Metabolite glucys_c__Synechococcus at 0x35a2afaf0>,
#  <Metabolite cynt_c__Synechococcus at 0x35a301460>,
#  <Metabolite h_u__Synechococcus at 0x35a42e9a0>,
#  <Metabolite 2ippm_c__Synechococcus at 0x35aff13a0>,
#  <Metabolite pre6b_c__Synechococcus at 0x35b0839d0>,
#  <Metabolite pre8_c__Synechococcus at 0x35b083be0>,
#  <Metabolite 2dda7p_c__Synechococcus at 0x35b05fbb0>,
#  <Metabolite achms_c__Synechococcus at 0x35b4daf10>,
#  <Metabolite 4mop_c__Synechococcus at 0x35b05fd00>,
#  <Metabolite adcobdam_c__Synechococcus at 0x35b0ad940>,
#  <Metabolite co1dam_c__Synechococcus at 0x35b509bb0>,
#  <Metabolite 2mecdp_c__Synechococcus at 0x35b908bb0>,
#  <Metabolite h_cx__Synechococcus at 0x35b504f40>,
#  <Metabolite ca2_e__Synechococcus at 0x35c0339a0>,
#  <Metabolite 3hbutACP_c__Synechococcus at 0x35c0a3e50>,
#  <Metabolite but2eACP_c__Synechococcus at 0x35c00f1c0>,
#  <Metabolite dgdg1619Z160_c__Synechococcus at 0x35c00f2b0>,
#  <Metabolite dgdg161_c__Synechococcus at 0x35c0d2280>,
#  <Metabolite dgdg1819Z160Z_c__Synechococcus at 0x35c0d2190>,
#  <Metabolite dgdg1819Z1619Z_c__Synechococcus at 0x35c0d2370>,
#  <Metabolite mgdg1619Z160_c__Synechococcus at 0x35c0d2ac0>,
#  <Metabolite mgdg161_c__Synechococcus at 0x35c0d71f0>,
#  <Metabolite mgdg1819Z160_c__Synechococcus at 0x35c0d73d0>,
#  <Metabolite mgdg1819Z1619Z_c__Synechococcus at 0x35c0f7e50>,
#  <Metabolite pg1819Z160_c__Synechococcus at 0x35c0fb2b0>,
#  <Metabolite sqdg160_c__Synechococcus at 0x35c0fb2e0>,
#  <Metabolite sqdg1619Z160_c__Synechococcus at 0x35c0fb310>,
#  <Metabolite hco3_cx__Synechococcus at 0x35c0fb610>,
#  <Metabolite glyald_c__Synechococcus at 0x35c120f10>,
#  <Metabolite alatrna_c__Synechococcus at 0x35c124130>,
#  <Metabolite argtrna_c__Synechococcus at 0x35c124280>,
#  <Metabolite asntrna_c__Synechococcus at 0x35c124340>,
#  <Metabolite asptrna_c__Synechococcus at 0x35c1246d0>,
#  <Metabolite cystrna_c__Synechococcus at 0x35c129760>,
#  <Metabolite glntrna_c__Synechococcus at 0x35c1292e0>,
#  <Metabolite glytrna_c__Synechococcus at 0x35c148d60>,
#  <Metabolite histrna_c__Synechococcus at 0x35c148f40>,
#  <Metabolite iletrna_c__Synechococcus at 0x35c14e040>,
#  <Metabolite leutrna_c__Synechococcus at 0x35c14e1c0>,
#  <Metabolite lystrna_c__Synechococcus at 0x35c14e490>,
#  <Metabolite mettrna_c__Synechococcus at 0x35c14e2b0>,
#  <Metabolite phetrna_c__Synechococcus at 0x35c14e4c0>,
#  <Metabolite protrna_c__Synechococcus at 0x35c14e4f0>,
#  <Metabolite sertrna_c__Synechococcus at 0x35c14e640>,
#  <Metabolite thrtrna_c__Synechococcus at 0x35c14e9d0>,
#  <Metabolite trnaala_c__Synechococcus at 0x35c14ecd0>,
#  <Metabolite trnaarg_c__Synechococcus at 0x35c14e7f0>,
#  <Metabolite trnaasn_c__Synechococcus at 0x35c1646d0>,
#  <Metabolite trnaasp_c__Synechococcus at 0x35c1535e0>,
#  <Metabolite trnacys_c__Synechococcus at 0x35c173100>,
#  <Metabolite trnagln_c__Synechococcus at 0x35c177280>,
#  <Metabolite trnagly_c__Synechococcus at 0x35c1773a0>,
#  <Metabolite trnahis_c__Synechococcus at 0x35c177310>,
#  <Metabolite trnaile_c__Synechococcus at 0x35c177460>,
#  <Metabolite trnaleu_c__Synechococcus at 0x35c177520>,
#  <Metabolite trnalys_c__Synechococcus at 0x35c1778b0>,
#  <Metabolite trnamet_c__Synechococcus at 0x35c177670>,
#  <Metabolite trnaphe_c__Synechococcus at 0x35c1776d0>,
#  <Metabolite trnapro_c__Synechococcus at 0x35c177bb0>,
#  <Metabolite trnaser_c__Synechococcus at 0x35c17d2e0>,
#  <Metabolite trnathr_c__Synechococcus at 0x35c17d490>,
#  <Metabolite trnatrp_c__Synechococcus at 0x35c17d4c0>,
#  <Metabolite trnatyr_c__Synechococcus at 0x35c17d610>,
#  <Metabolite trnaval_c__Synechococcus at 0x35c17d7f0>,
#  <Metabolite trptrna_c__Synechococcus at 0x35c17d940>,
#  <Metabolite tyrtrna_c__Synechococcus at 0x35c18d5b0>,
#  <Metabolite valtrna_c__Synechococcus at 0x35c18dfd0>,
#  <Metabolite nh4_e__Synechococcus at 0x35c19cf40>,
#  <Metabolite dgdp_c__Synechococcus at 0x35c1a0490>,
#  <Metabolite 3odecACP_c__Synechococcus at 0x35c1a0340>,
#  <Metabolite ocACP_c__Synechococcus at 0x35c1a05b0>,
#  <Metabolite 25aics_c__Synechococcus at 0x35c1d7f10>,
#  <Metabolite 1p3h5c_c__Synechococcus at 0x35c1a0910>,
#  <Metabolite 3oddecACP_c__Synechococcus at 0x35c288a00>,
#  <Metabolite dcaACP_c__Synechococcus at 0x35c2889a0>,
#  <Metabolite 3dhq_c__Synechococcus at 0x35c3376d0>,
#  <Metabolite 3dhsk_c__Synechococcus at 0x35c2c1e20>,
#  <Metabolite 3ohexACP_c__Synechococcus at 0x35c3715e0>,
#  <Metabolite butACP_c__Synechococcus at 0x35c371490>,
#  <Metabolite mg2_c__Synechococcus at 0x35c418f40>,
#  <Metabolite mg2_p__Synechococcus at 0x35c2fc4f0>,
#  <Metabolite alac__S_c__Synechococcus at 0x35c424820>,
#  <Metabolite r5p_c__Synechococcus at 0x35c45c760>,
#  <Metabolite ptrc_p__Synechococcus at 0x35c4983a0>,
#  <Metabolite 2pg_c__Synechococcus at 0x35c580b80>,
#  <Metabolite ni2_c__Synechococcus at 0x35c3e6130>,
#  <Metabolite ni2_p__Synechococcus at 0x35c6389d0>,
#  <Metabolite k_p__Synechococcus at 0x35c69a370>,
#  <Metabolite dtdp4d6dm_c__Synechococcus at 0x35c5f57c0>,
#  <Metabolite dtdprmn_c__Synechococcus at 0x35c82eac0>,
#  <Metabolite uacgam_c__Synechococcus at 0x35cb60a90>,
#  <Metabolite dtdp4d6dg_c__Synechococcus at 0x35cefb0d0>,
#  <Metabolite fmn_c__Synechococcus at 0x35d5a9ac0>,
#  <Metabolite no2_c__Synechococcus at 0x35da584f0>,
#  <Metabolite dscl_c__Synechococcus at 0x35da811c0>,
#  <Metabolite 14dhncoa_c__Synechococcus at 0x35dad5f10>,
#  <Metabolite malcoa_c__Synechococcus at 0x35dafd430>,
#  <Metabolite gthox_c__Synechococcus at 0x35db30ee0>,
#  <Metabolite citr__L_c__Synechococcus at 0x35db60e80>,
#  <Metabolite hmbil_c__Synechococcus at 0x35dc0ff10>,
#  <Metabolite 2pglyc_c__Synechococcus at 0x35daaa460>,
#  <Metabolite citm_c__Synechococcus at 0x35e2e1bb0>,
#  <Metabolite cgly_c__Synechococcus at 0x35e6cc3d0>,
#  <Metabolite sprm_c__Synechococcus at 0x35e2d95b0>,
#  <Metabolite quln_c__Synechococcus at 0x35f289e20>,
#  <Metabolite cu2_c__Synechococcus at 0x35f5614f0>,
#  <Metabolite cu2_p__Synechococcus at 0x35fb98130>,
#  <Metabolite pran_c__Synechococcus at 0x35dcf94c0>,
#  <Metabolite 2h3oppan_c__Synechococcus at 0x36071aa00>,
#  <Metabolite cynt_p__Synechococcus at 0x360751f70>,
#  <Metabolite 2pglyc_cx__Synechococcus at 0x3607a1fd0>,
#  <Metabolite co2_cx__Synechococcus at 0x3607a1be0>,
#  <Metabolite h2o_cx__Synechococcus at 0x36077d670>,
#  <Metabolite mobd_c__Synechococcus at 0x35fba9c70>,
#  <Metabolite mobd_p__Synechococcus at 0x3608505b0>,
#  <Metabolite fe3_p__Synechococcus at 0x36103f220>,
#  <Metabolite co2_e__Synechococcus at 0x36199c430>,
#  <Metabolite co2_p__Synechococcus at 0x361a9aee0>,
#  <Metabolite hdeACP_c__Synechococcus at 0x362133c10>,
#  <Metabolite fe2_e__Synechococcus at 0x3621335e0>,
#  <Metabolite cu2_e__Synechococcus at 0x3626f82e0>,
#  <Metabolite 3ooctdACP_c__Synechococcus at 0x3628386a0>,
#  <Metabolite myrsACP_c__Synechococcus at 0x362883d90>,
#  <Metabolite k_e__Synechococcus at 0x3628ade80>,
#  <Metabolite leu__L_e__Synechococcus at 0x362dbf4c0>,
#  <Metabolite 2obut_c__Synechococcus at 0x362dd2460>,
#  <Metabolite cobalt2_e__Synechococcus at 0x362dd7280>,
#  <Metabolite no3_e__Synechococcus at 0x362df6dc0>,
#  <Metabolite zn2_e__Synechococcus at 0x362dfb3a0>,
#  <Metabolite fe3_e__Synechococcus at 0x362dfb790>,
#  <Metabolite so4_e__Synechococcus at 0x362e243a0>,
#  <Metabolite spmd_e__Synechococcus at 0x362e24be0>,
#  <Metabolite mobd_e__Synechococcus at 0x362e294f0>,
#  <Metabolite ni2_e__Synechococcus at 0x362e4d4c0>,
#  <Metabolite ugmd_c__Synechococcus at 0x362e4d820>,
#  <Metabolite glc__D_c__Synechococcus at 0x362e85a90>,
#  <Metabolite dudp_c__Synechococcus at 0x362e76820>,
#  <Metabolite dump_c__Synechococcus at 0x362e53d00>,
#  <Metabolite na1_e__Synechococcus at 0x362e53100>,
#  <Metabolite pi_p__Synechococcus at 0x362edc730>,
#  <Metabolite 5g2oxpt_p__Synechococcus at 0x363052d60>,
#  <Metabolite h2o2_p__Synechococcus at 0x363052a60>,
#  <Metabolite phe__L_c__Synechococcus at 0x363018790>,
#  <Metabolite 2ahbut_c__Synechococcus at 0x3630526d0>,
#  <Metabolite 2ahethmpp_c__Synechococcus at 0x3633af0d0>,
#  <Metabolite cynt_e__Synechococcus at 0x3639d2400>,
#  <Metabolite mthgxl_c__Synechococcus at 0x364171340>,
#  <Metabolite 5mdru1p_c__Synechococcus at 0x36418e820>,
#  <Metabolite no3_c__Synechococcus at 0x3645231f0>,
#  <Metabolite fe2_p__Synechococcus at 0x3645c1cd0>,
#  <Metabolite prlp_c__Synechococcus at 0x3646f9a30>,
#  <Metabolite ugmda_c__Synechococcus at 0x3659b7250>,
#  <Metabolite pgp1819Z160_c__Synechococcus at 0x366293bb0>,
#  <Metabolite meoh_c__Synechococcus at 0x366a45a00>,
#  <Metabolite meoh_p__Synechococcus at 0x366a45820>,
#  <Metabolite meoh_e__Synechococcus at 0x366a45f40>,
#  <Metabolite photon410_e__Synechococcus at 0x366a6aa90>,
#  <Metabolite photon430_e__Synechococcus at 0x366a70160>,
#  <Metabolite photon450_e__Synechococcus at 0x366a70eb0>,
#  <Metabolite photon470_e__Synechococcus at 0x366a93580>,
#  <Metabolite photon490_e__Synechococcus at 0x366a936d0>,
#  <Metabolite photon510_e__Synechococcus at 0x366a938b0>,
#  <Metabolite amob_c__Synechococcus at 0x366a939a0>,
#  <Metabolite epmeACP_c__Synechococcus at 0x366a93af0>,
#  <Metabolite hpmeACP_c__Synechococcus at 0x366a93b20>,
#  <Metabolite opmeACP_c__Synechococcus at 0x366a93c10>,
#  <Metabolite photon530_e__Synechococcus at 0x366a93ca0>,
#  <Metabolite photon550_e__Synechococcus at 0x366a93dc0>,
#  <Metabolite sucr_c__Synechococcus at 0x366a9d310>,
#  <Metabolite 1hdecg3p_c__Synechococcus at 0x366a9d460>,
#  <Metabolite pa160_c__Synechococcus at 0x366aa16a0>,
#  <Metabolite photon570_e__Synechococcus at 0x366ac5400>,
#  <Metabolite photon590_e__Synechococcus at 0x366aca5b0>,
#  <Metabolite photon610_e__Synechococcus at 0x366aee5b0>,
#  <Metabolite 1hdec9eg3p_c__Synechococcus at 0x366af3520>,
#  <Metabolite pa1619Z160_c__Synechococcus at 0x366af39d0>,
#  <Metabolite leu__L_p__Synechococcus at 0x366af36a0>,
#  <Metabolite btn_c__Synechococcus at 0x366b18580>,
#  <Metabolite dtbt_c__Synechococcus at 0x366b184c0>,
#  <Metabolite preq1_c__Synechococcus at 0x366b1d4f0>,
#  <Metabolite preqtrna_c__Synechococcus at 0x366b408e0>,
#  <Metabolite photon630_e__Synechococcus at 0x366b40640>,
#  <Metabolite photon650_e__Synechococcus at 0x366b405e0>,
#  <Metabolite photon670_e__Synechococcus at 0x366ba4ee0>,
#  <Metabolite photon690_e__Synechococcus at 0x366f84af0>,
#  <Metabolite pimACP_c__Synechococcus at 0x366f84e50>,
#  <Metabolite pmeACP_c__Synechococcus at 0x366f84d60>,
#  <Metabolite glcdg161_c__Synechococcus at 0x366e9b040>,
#  <Metabolite 1odec9eg3p_c__Synechococcus at 0x366e9b3d0>,
#  <Metabolite glcdg1819Z1619Z_c__Synechococcus at 0x366e9b6d0>,
#  <Metabolite glcdg1819Z160_c__Synechococcus at 0x367366970>,
#  <Metabolite glcdg1619Z160_c__Synechococcus at 0x3676e5880>,
#  <Metabolite gln__L_p__Synechococcus at 0x366e9bf70>,
#  <Metabolite pa161_c__Synechococcus at 0x367a412e0>,
#  <Metabolite pa1819Z1619Z_c__Synechococcus at 0x367a41b20>,
#  <Metabolite pa1819Z160_c__Synechococcus at 0x367a894f0>,
#  <Metabolite 12dgr1819Z1619Z_c__Synechococcus at 0x367ab2310>,
#  <Metabolite 12dgr1819Z160_c__Synechococcus at 0x367a60100>,
#  <Metabolite 12dgr1619Z160_c__Synechococcus at 0x367b04730>,
#  <Metabolite 12dgr161_c__Synechococcus at 0x367afbaf0>,
#  <Metabolite tyr__L_c__Synechococcus at 0x367b57f40>,
#  <Metabolite 12dgr160_c__Synechococcus at 0x367b7df70>,
#  <Metabolite so4_p__Synechococcus at 0x367c67c40>,
#  <Metabolite cdp12dgr1819Z160_c__Synechococcus at 0x367cc2070>,
#  <Metabolite no3_p__Synechococcus at 0x367d4f760>,
#  <Metabolite pi_e__Synechococcus at 0x3687e4e80>,
#  <Metabolite udpglcur_c__Synechococcus at 0x36890ce50>,
#  <Metabolite udpxyl_c__Synechococcus at 0x36890ce20>,
#  <Metabolite dann_c__Synechococcus at 0x368d3d2b0>,
#  <Metabolite leu__L_c__Synechococcus at 0x368d51280>,
#  <Metabolite ile__L_c__Synechococcus at 0x368d7a610>,
#  <Metabolite phptna_c__Synechococcus at 0x368da3a60>,
#  <Metabolite 8aonn_c__Synechococcus at 0x368df7550>,
#  <Metabolite octapb_c__Synechococcus at 0x368dcc490>,
#  <Metabolite fmettrna_c__Synechococcus at 0x368eaed00>,
#  <Metabolite accp_c__Synechococcus at 0x369367f10>,
#  <Metabolite btnCCP_c__Synechococcus at 0x368eaeca0>,
#  <Metabolite lipamp_c__Synechococcus at 0x3692c8a60>,
#  <Metabolite lipoate_c__Synechococcus at 0x3693df2e0>,
#  <Metabolite bcaro_exc_c__Synechococcus at 0x3694276d0>,
#  <Metabolite chla_soret_exc_c__Synechococcus at 0x3693d7f70>,
#  <Metabolite zeax_exc_c__Synechococcus at 0x368ee8a90>,
#  <Metabolite cph4_c__Synechococcus at 0x369865130>,
#  <Metabolite hgmeACP_c__Synechococcus at 0x369865460>,
#  <Metabolite ogmeACP_c__Synechococcus at 0x3698655b0>,
#  <Metabolite cdg_c__Synechococcus at 0x369865760>,
#  <Metabolite preq0_c__Synechococcus at 0x3698a64f0>,
#  <Metabolite phycy_exc_c__Synechococcus at 0x3698ca820>,
#  <Metabolite ttclyco_c__Synechococcus at 0x3698f87c0>,
#  <Metabolite epxqtrna_c__Synechococcus at 0x369917e80>,
#  <Metabolite quetrna_c__Synechococcus at 0x36991c2b0>,
#  <Metabolite ura_c__Synechococcus at 0x369946490>,
#  <Metabolite dczcaro_c__Synechococcus at 0x369d6bb20>,
#  <Metabolite gdpddman_c__Synechococcus at 0x369dd8970>,
#  <Metabolite gdpfuc_c__Synechococcus at 0x369df72e0>,
#  <Metabolite chla_qy1_exc_c__Synechococcus at 0x369dfda90>,
#  <Metabolite chla_qy2_exc_c__Synechococcus at 0x369dd8790>,
#  <Metabolite pho_loss_c__Synechococcus at 0x369f26eb0>,
#  <Metabolite colipacy_p__Synechococcus at 0x369f79940>,
#  <Metabolite alaala_p__Synechococcus at 0x369f7e0a0>,
#  <Metabolite murein3px4p_p__Synechococcus at 0x369f7e8b0>,
#  <Metabolite murein5px4p_p__Synechococcus at 0x369f7ed60>,
#  <Metabolite cdp4dh6doglc_c__Synechococcus at 0x369fa1760>,
#  <Metabolite ocdca_c__Synechococcus at 0x369fa1910>,
#  <Metabolite ocdcal_c__Synechococcus at 0x369fa1790>,
#  <Metabolite glyc_c__Synechococcus at 0x369fa17c0>,
#  <Metabolite 2c4mthzep_c__Synechococcus at 0x36a00ee80>,
#  <Metabolite ala__D_p__Synechococcus at 0x369fa6be0>,
#  <Metabolite murein4p3p_p__Synechococcus at 0x369fd2d30>,
#  <Metabolite murein4p4p_p__Synechococcus at 0x369fd2f70>,
#  <Metabolite tczcaro_c__Synechococcus at 0x36a04aa00>,
#  <Metabolite murein5p3p_p__Synechococcus at 0x36a0c4b20>,
#  <Metabolite murein5p5p_p__Synechococcus at 0x36a0bc520>,
#  <Metabolite murein3p3p_p__Synechococcus at 0x36a5179d0>,
#  <Metabolite LalaLglu_c__Synechococcus at 0x36a517df0>,
#  <Metabolite anhgm4p_c__Synechococcus at 0x36a2fff40>,
#  <Metabolite anhgm4p_p__Synechococcus at 0x36a2ffd00>,
#  <Metabolite anhgm_c__Synechococcus at 0x36a3df3a0>,
#  <Metabolite anhgm_p__Synechococcus at 0x36a52d9a0>,
#  <Metabolite malcoame_c__Synechococcus at 0x36a5380a0>,
#  <Metabolite ara5p_c__Synechococcus at 0x36a5569d0>,
#  <Metabolite kdo8p_c__Synechococcus at 0x36a55c400>,
#  <Metabolite kdo_c__Synechococcus at 0x36a580a90>,
#  <Metabolite no2_e__Synechococcus at 0x36a5b0dc0>,
#  <Metabolite no2_p__Synechococcus at 0x36a5b03d0>,
#  <Metabolite ckdo_c__Synechococcus at 0x36a5d92e0>,
#  <Metabolite egmeACP_c__Synechococcus at 0x36a5fcfd0>,
#  <Metabolite gmeACP_c__Synechococcus at 0x36a5fccd0>,
#  <Metabolite imgly_c__Synechococcus at 0x36a602be0>,
#  <Metabolite this_c__Synechococcus at 0x36a5fc190>,
#  <Metabolite thissh_c__Synechococcus at 0x36a5fcc70>,
#  <Metabolite uacmam_c__Synechococcus at 0x36a62aaf0>,
#  <Metabolite oanticy_c__Synechococcus at 0x36a656b50>,
#  <Metabolite udcpp_c__Synechococcus at 0x36a6d5a60>,
#  <Metabolite unaga_c__Synechococcus at 0x36a6d5c10>,
#  <Metabolite allocy_c__Synechococcus at 0x36a6ccdf0>,
#  <Metabolite allocy_exc_c__Synechococcus at 0x36a693ac0>,
#  <Metabolite fldox_c__Synechococcus at 0x36ab9db20>,
#  <Metabolite fldrd_c__Synechococcus at 0x36ab9db50>,
#  <Metabolite unagam_c__Synechococcus at 0x36ab9deb0>,
#  <Metabolite icolipacy_c__Synechococcus at 0x36aa6a1c0>,
#  <Metabolite icolipacy_p__Synechococcus at 0x36aa6a160>,
#  <Metabolite kdolipid4cy_c__Synechococcus at 0x36aa8d2b0>,
#  <Metabolite uaagmda_c__Synechococcus at 0x36abf03a0>,
#  <Metabolite uagmda_c__Synechococcus at 0x36ac14280>,
#  <Metabolite LalaDgluMdapDala_c__Synechococcus at 0x36b368fd0>,
#  <Metabolite um4p_c__Synechococcus at 0x36ac141f0>,
#  <Metabolite LalaDgluMdap_c__Synechococcus at 0x36b6a26d0>,
#  <Metabolite oanticy_p__Synechococcus at 0x36ac0fe20>,
#  <Metabolite murein4px4p_p__Synechococcus at 0x36ba3af40>,
#  <Metabolite murein4px4px4p_p__Synechococcus at 0x36ba900a0>,
#  <Metabolite murein5px4px4p_p__Synechococcus at 0x36ba62430>,
#  <Metabolite anhgm3p_p__Synechococcus at 0x36c9aca30>,
#  <Metabolite murein4px4p4p_p__Synechococcus at 0x36c9acd30>,
#  <Metabolite fald_c__Synechococcus at 0x36c9b2460>,
#  <Metabolite hmgth_c__Synechococcus at 0x36c9b2640>,
#  <Metabolite cl_e__Synechococcus at 0x36d1018e0>,
#  <Metabolite cl_p__Synechococcus at 0x36d101700>,
#  <Metabolite anhm3p_c__Synechococcus at 0x36d251340>,
#  <Metabolite anhm_c__Synechococcus at 0x36d2516d0>,
#  <Metabolite anhm4p_c__Synechococcus at 0x36d276f40>,
#  <Metabolite LalaDgluMdap_p__Synechococcus at 0x36d27bfa0>,
#  <Metabolite LalaDgluMdapDala_p__Synechococcus at 0x36d2a6340>,
#  <Metabolite dkmpp_c__Synechococcus at 0x36d2a6160>,
#  <Metabolite ps2d1_exc_um__Synechococcus at 0x36d323160>,
#  <Metabolite ps2d1_um__Synechococcus at 0x36d3235b0>,
#  <Metabolite anhgm3p_c__Synechococcus at 0x36d3592e0>,
#  <Metabolite acgam_c__Synechococcus at 0x36d3c2df0>,
#  <Metabolite p680_exc_um__Synechococcus at 0x36d3cdee0>,
#  <Metabolite p680_um__Synechococcus at 0x36d389f10>,
#  <Metabolite dhmtp_c__Synechococcus at 0x36d472c70>,
#  <Metabolite LalaDglu_c__Synechococcus at 0x36d472f10>,
#  <Metabolite b14glucan_c__Synechococcus at 0x36d4f4040>,
#  <Metabolite 2kmb_c__Synechococcus at 0x36d60a790>,
#  <Metabolite phphbda_c__Synechococcus at 0x36e407220>,
#  <Metabolite phytol_c__Synechococcus at 0x36e407f10>,
#  <Metabolite murein5px3p_p__Synechococcus at 0x36e92c220>,
#  <Metabolite 34hpp_c__Synechococcus at 0x36fb60fa0>,
#  <Metabolite rcc_c__Synechococcus at 0x36fac6310>,
#  <Metabolite tdec2eACP_c__Synechococcus at 0x36fb60fd0>,
#  <Metabolite e4hglu_c__Synechococcus at 0x36ff03a30>,
#  <Metabolite Sfglutth_c__Synechococcus at 0x37037bc40>,
#  <Metabolite 3hddecACP_c__Synechococcus at 0x37048f100>,
#  <Metabolite 6pthp_c__Synechococcus at 0x3708c9e20>,
#  <Metabolite 3hdecACP_c__Synechococcus at 0x370cd06a0>,
#  <Metabolite 5oxpro_c__Synechococcus at 0x37195bbb0>,
#  <Metabolite thbpt_c__Synechococcus at 0x371609ca0>,
#  <Metabolite acgam6p_c__Synechococcus at 0x371bab7c0>,
#  <Metabolite acmanap_c__Synechococcus at 0x371def1c0>,
#  <Metabolite acmum6p_c__Synechococcus at 0x371e0fd00>,
#  <Metabolite cl_c__Synechococcus at 0x372b82040>,
#  <Metabolite k_u__Synechococcus at 0x372b63c40>,
#  <Metabolite athis_c__Synechococcus at 0x372a7c070>,
#  <Metabolite iscsh_c__Synechococcus at 0x37339b160>,
#  <Metabolite iscssh_c__Synechococcus at 0x3731cbc10>,
#  <Metabolite murein5p4p_p__Synechococcus at 0x37561b280>,
#  <Metabolite sucr_e__Synechococcus at 0x3771d49d0>,
#  <Metabolite gln__L_m at 0x34fe31400>,
#  <Metabolite hco3_m at 0x34fe31520>,
#  <Metabolite mn2_m at 0x34fe31610>,
#  <Metabolite arg__L_m at 0x34fe31700>,
#  <Metabolite mg2_m at 0x352905fa0>,
#  <Metabolite ptrc_m at 0x355040040>,
#  <Metabolite ca2_m at 0x35bc86130>,
#  <Metabolite nh4_m at 0x35c1a00d0>,
#  <Metabolite fe2_m at 0x3624cda60>,
#  <Metabolite cu2_m at 0x3626f87c0>,
#  <Metabolite k_m at 0x3628897f0>,
#  <Metabolite h2o_m at 0x362d930d0>,
#  <Metabolite o2_m at 0x362da4310>,
#  <Metabolite co2_m at 0x362da8430>,
#  <Metabolite leu__L_m at 0x362dae3d0>,
#  <Metabolite cobalt2_m at 0x362dd2250>,
#  <Metabolite no3_m at 0x362df6df0>,
#  <Metabolite zn2_m at 0x362dfb490>,
#  <Metabolite fe3_m at 0x362dfbcd0>,
#  <Metabolite so4_m at 0x362e24130>,
#  <Metabolite spmd_m at 0x362e246a0>,
#  <Metabolite mobd_m at 0x362e29820>,
#  <Metabolite ni2_m at 0x362e4d190>,
#  <Metabolite na1_m at 0x362e539d0>,
#  <Metabolite cynt_m at 0x3635e7280>,
#  <Metabolite h_m at 0x363d1a730>,
#  <Metabolite photon410_m at 0x366a6ae20>,
#  <Metabolite photon430_m at 0x366a70a00>,
#  <Metabolite photon450_m at 0x366a85100>,
#  <Metabolite photon470_m at 0x366a93400>,
#  <Metabolite photon490_m at 0x366a937f0>,
#  <Metabolite photon510_m at 0x366a938e0>,
#  <Metabolite photon530_m at 0x366a93b80>,
#  <Metabolite photon550_m at 0x366a93f10>,
#  <Metabolite photon570_m at 0x366ac5610>,
#  <Metabolite photon590_m at 0x366adb550>,
#  <Metabolite photon610_m at 0x366aee4f0>,
#  <Metabolite photon630_m at 0x366b40790>,
#  <Metabolite photon650_m at 0x366b40940>,
#  <Metabolite photon670_m at 0x366ba4f10>,
#  <Metabolite photon690_m at 0x366f84b80>,
#  <Metabolite pi_m at 0x3687ed160>,
#  <Metabolite meoh_m at 0x36a587eb0>,
#  <Metabolite cl_m at 0x36d24de50>,
#  <Metabolite sucr_m at 0x3772fc640>,
#  <Metabolite ala__D_c__Azotobacter at 0x3779b4550>,
#  <Metabolite pyam5p_c__Azotobacter at 0x3779b4580>,
#  <Metabolite pydx5p_c__Azotobacter at 0x3779b45b0>,
#  <Metabolite pyr_c__Azotobacter at 0x3779b45e0>,
#  <Metabolite dscl_c__Azotobacter at 0x3779b4700>,
#  <Metabolite h_c__Azotobacter at 0x3779b4670>,
#  <Metabolite nad_c__Azotobacter at 0x3779b4610>,
#  <Metabolite nadh_c__Azotobacter at 0x3779b4640>,
#  <Metabolite scl_c__Azotobacter at 0x3779b4790>,
#  <Metabolite co2_c__Azotobacter at 0x3779b4a30>,
#  <Metabolite cpppg3_c__Azotobacter at 0x3779b4ac0>,
#  <Metabolite h2o_c__Azotobacter at 0x3779b49a0>,
#  <Metabolite o2_c__Azotobacter at 0x3779b4910>,
#  <Metabolite pppg9_c__Azotobacter at 0x3779b48b0>,
#  <Metabolite gthox_c__Azotobacter at 0x3779b4d90>,
#  <Metabolite gthrd_c__Azotobacter at 0x3779b47c0>,
#  <Metabolite nadp_c__Azotobacter at 0x3779b4760>,
#  <Metabolite nadph_c__Azotobacter at 0x3779b4a60>,
#  <Metabolite dhor__S_c__Azotobacter at 0x3779daeb0>,
#  <Metabolite mql8_c__Azotobacter at 0x3779dad00>,
#  <Metabolite mqn8_c__Azotobacter at 0x3779b7220>,
#  <Metabolite orot_c__Azotobacter at 0x3779b7fa0>,
#  <Metabolite glx_c__Azotobacter at 0x377d7a8e0>,
#  <Metabolite glyclt_c__Azotobacter at 0x377d71370>,
#  <Metabolite q8_c__Azotobacter at 0x377d716a0>,
#  <Metabolite q8h2_c__Azotobacter at 0x377d71100>,
#  <Metabolite 2dmmq8_c__Azotobacter at 0x377dbc550>,
#  <Metabolite 2dmmql8_c__Azotobacter at 0x377db7640>,
#  <Metabolite indole_c__Azotobacter at 0x377d71700>,
#  <Metabolite ser__L_c__Azotobacter at 0x3780808e0>,
#  <Metabolite trp__L_c__Azotobacter at 0x37817eca0>,
#  <Metabolite dhap_c__Azotobacter at 0x37815a1f0>,
#  <Metabolite glyc3p_c__Azotobacter at 0x377db75e0>,
#  <Metabolite cellb_e__Azotobacter at 0x3781aa460>,
#  <Metabolite chol_e__Azotobacter at 0x37880f6d0>,
#  <Metabolite 4mop_c__Azotobacter at 0x378841520>,
#  <Metabolite akg_c__Azotobacter at 0x378845850>,
#  <Metabolite glu__L_c__Azotobacter at 0x378b4fb80>,
#  <Metabolite leu__L_c__Azotobacter at 0x378b4fe20>,
#  <Metabolite 3dhsk_c__Azotobacter at 0x378b66460>,
#  <Metabolite skm_c__Azotobacter at 0x378b66130>,
#  <Metabolite glu5p_c__Azotobacter at 0x378b837c0>,
#  <Metabolite glu5sa_c__Azotobacter at 0x378b83700>,
#  <Metabolite pi_c__Azotobacter at 0x378b83670>,
#  <Metabolite ala__L_c__Azotobacter at 0x378b83130>,
#  <Metabolite 5aprbu_c__Azotobacter at 0x378bdb100>,
#  <Metabolite 5apru_c__Azotobacter at 0x378b83910>,
#  <Metabolite db4p_c__Azotobacter at 0x378bd4e20>,
#  <Metabolite for_c__Azotobacter at 0x378b83640>,
#  <Metabolite ru5p__D_c__Azotobacter at 0x378b83520>,
#  <Metabolite adp_c__Azotobacter at 0x379394490>,
#  <Metabolite atp_c__Azotobacter at 0x379054f40>,
#  <Metabolite fmn_c__Azotobacter at 0x37904e610>,
#  <Metabolite ribflv_c__Azotobacter at 0x37902ca90>,
#  <Metabolite 4r5au_c__Azotobacter at 0x3793c9220>,
#  <Metabolite dmlz_c__Azotobacter at 0x3793c92b0>,
#  <Metabolite pi_e__Azotobacter at 0x3793e6310>,
#  <Metabolite h_e__Azotobacter at 0x37974c820>,
#  <Metabolite dmpp_c__Azotobacter at 0x37974cf40>,
#  <Metabolite grdp_c__Azotobacter at 0x37962d160>,
#  <Metabolite ipdp_c__Azotobacter at 0x379771af0>,
#  <Metabolite ppi_c__Azotobacter at 0x379771880>,
#  <Metabolite frdp_c__Azotobacter at 0x379776340>,
#  <Metabolite hmbil_c__Azotobacter at 0x37977a0d0>,
#  <Metabolite uppg3_c__Azotobacter at 0x379771bb0>,
#  <Metabolite ade_e__Azotobacter at 0x3797c3af0>,
#  <Metabolite 4abut_e__Azotobacter at 0x379a63130>,
#  <Metabolite ac_e__Azotobacter at 0x379eafa30>,
#  <Metabolite akg_e__Azotobacter at 0x379eaff70>,
#  <Metabolite ala__L_e__Azotobacter at 0x379ed5820>,
#  <Metabolite asp__L_e__Azotobacter at 0x379ed5ac0>,
#  <Metabolite cytd_e__Azotobacter at 0x379edb190>,
#  <Metabolite dcyt_e__Azotobacter at 0x379edbee0>,
#  <Metabolite fum_e__Azotobacter at 0x379efe5b0>,
#  <Metabolite gua_e__Azotobacter at 0x379efe700>,
#  <Metabolite hco3_c__Azotobacter at 0x379efe8e0>,
#  <Metabolite fprica_c__Azotobacter at 0x379efea00>,
#  <Metabolite imp_c__Azotobacter at 0x379efe970>,
#  <Metabolite xmp_c__Azotobacter at 0x379efebb0>,
#  <Metabolite 3hdcoa_c__Azotobacter at 0x379efeca0>,
#  <Metabolite dc2coa_c__Azotobacter at 0x379efe940>,
#  <Metabolite amp_c__Azotobacter at 0x379f064c0>,
#  <Metabolite glutrna_c__Azotobacter at 0x379f061f0>,
#  <Metabolite trnaglu_c__Azotobacter at 0x379efef10>,
#  <Metabolite 2mahmp_c__Azotobacter at 0x379f2d1f0>,
#  <Metabolite 4mpetz_c__Azotobacter at 0x379f2d160>,
#  <Metabolite thmmp_c__Azotobacter at 0x379efea90>,
#  <Metabolite dgdp_c__Azotobacter at 0x379f79f70>,
#  <Metabolite dgtp_c__Azotobacter at 0x379f79ee0>,
#  <Metabolite cbasp_c__Azotobacter at 0x379efe910>,
#  <Metabolite orot5p_c__Azotobacter at 0x37a379670>,
#  <Metabolite ump_c__Azotobacter at 0x37a35f2e0>,
#  <Metabolite accoa_c__Azotobacter at 0x37a39d130>,
#  <Metabolite cit_c__Azotobacter at 0x37a35f760>,
#  <Metabolite coa_c__Azotobacter at 0x37a35f730>,
#  <Metabolite oaa_c__Azotobacter at 0x37a35f700>,
#  <Metabolite icit_c__Azotobacter at 0x37a3ca310>,
#  <Metabolite acald_c__Azotobacter at 0x37a72aeb0>,
#  <Metabolite ac_c__Azotobacter at 0x37a756bb0>,
#  <Metabolite pep_c__Azotobacter at 0x37aca64f0>,
#  <Metabolite xu5p__D_c__Azotobacter at 0x37afd57f0>,
#  <Metabolite xylu__D_c__Azotobacter at 0x37aff9190>,
#  <Metabolite glyc_c__Azotobacter at 0x37b314df0>,
#  <Metabolite asp__L_c__Azotobacter at 0x37a779c40>,
#  <Metabolite f6p_c__Azotobacter at 0x37b6aa580>,
#  <Metabolite fdp_c__Azotobacter at 0x37b6aa370>,
#  <Metabolite ara5p_c__Azotobacter at 0x37ba66cd0>,
#  <Metabolite metsox_S__L_e__Azotobacter at 0x37b9eab50>,
#  <Metabolite 2ippm_c__Azotobacter at 0x37ba42220>,
#  <Metabolite 3c3hmp_c__Azotobacter at 0x37ba42df0>,
#  <Metabolite 2ahbut_c__Azotobacter at 0x37c1830d0>,
#  <Metabolite 2obut_c__Azotobacter at 0x37c183c10>,
#  <Metabolite alac__S_c__Azotobacter at 0x37ba42040>,
#  <Metabolite 3psme_c__Azotobacter at 0x37ba3c1c0>,
#  <Metabolite skm5p_c__Azotobacter at 0x37bdbb370>,
#  <Metabolite anth_c__Azotobacter at 0x37c192e80>,
#  <Metabolite chor_c__Azotobacter at 0x37c192790>,
#  <Metabolite gln__L_c__Azotobacter at 0x37bdbb2e0>,
#  <Metabolite pran_c__Azotobacter at 0x37c91f550>,
#  <Metabolite prpp_c__Azotobacter at 0x37c600e50>,
#  <Metabolite pphn_c__Azotobacter at 0x37c94f3a0>,
#  <Metabolite 2cpr5p_c__Azotobacter at 0x37bdbb460>,
#  <Metabolite 3ig3p_c__Azotobacter at 0x37cc92af0>,
#  <Metabolite crn_e__Azotobacter at 0x37ccbba60>,
#  <Metabolite fe3_e__Azotobacter at 0x37cff8a30>,
#  <Metabolite glcn_e__Azotobacter at 0x37d020130>,
#  <Metabolite gln__L_e__Azotobacter at 0x37d025160>,
#  <Metabolite glyc_e__Azotobacter at 0x37d03a580>,
#  <Metabolite man_e__Azotobacter at 0x37d049910>,
#  <Metabolite mn2_e__Azotobacter at 0x37d049c10>,
#  <Metabolite rib__D_e__Azotobacter at 0x37d04fa00>,
#  <Metabolite sbt__D_e__Azotobacter at 0x37d064550>,
#  <Metabolite 3htdcoa_c__Azotobacter at 0x37d0724c0>,
#  <Metabolite td2coa_c__Azotobacter at 0x37d072580>,
#  <Metabolite 2pg_c__Azotobacter at 0x37d0729a0>,
#  <Metabolite g6p_c__Azotobacter at 0x37d07a880>,
#  <Metabolite 13dpg_c__Azotobacter at 0x37d7ee040>,
#  <Metabolite 3pg_c__Azotobacter at 0x37d43e130>,
#  <Metabolite 2ddg6p_c__Azotobacter at 0x37d420970>,
#  <Metabolite g3p_c__Azotobacter at 0x37d40ea00>,
#  <Metabolite e4p_c__Azotobacter at 0x37d072610>,
#  <Metabolite s7p_c__Azotobacter at 0x37d072910>,
#  <Metabolite r5p_c__Azotobacter at 0x37dbe4d60>,
#  <Metabolite etoh_c__Azotobacter at 0x37df76eb0>,
#  <Metabolite ura_e__Azotobacter at 0x37df7bca0>,
#  <Metabolite xan_e__Azotobacter at 0x37dbb0670>,
#  <Metabolite fad_c__Azotobacter at 0x37e650850>,
#  <Metabolite nmn_c__Azotobacter at 0x37e6509a0>,
#  <Metabolite 4ahmmp_c__Azotobacter at 0x37e676970>,
#  <Metabolite 4ampm_c__Azotobacter at 0x37e676dc0>,
#  <Metabolite dudp_c__Azotobacter at 0x37e9fd550>,
#  <Metabolite dutp_c__Azotobacter at 0x37e9d6e80>,
#  <Metabolite dadp_c__Azotobacter at 0x37eceba30>,
#  <Metabolite datp_c__Azotobacter at 0x37e9d6970>,
#  <Metabolite 4abutn_c__Azotobacter at 0x37ed6eca0>,
#  <Metabolite ptrc_c__Azotobacter at 0x37ed6ea00>,
#  <Metabolite cys__L_c__Azotobacter at 0x37ec6f070>,
#  <Metabolite h2s_c__Azotobacter at 0x37ec6f370>,
#  <Metabolite nh4_c__Azotobacter at 0x37ed6e910>,
#  <Metabolite co2_e__Azotobacter at 0x37f13af70>,
#  <Metabolite 3mop_c__Azotobacter at 0x37f3eee80>,
#  <Metabolite ile__L_c__Azotobacter at 0x37f3ee9d0>,
#  <Metabolite 3mob_c__Azotobacter at 0x37f3ee820>,
#  <Metabolite val__L_c__Azotobacter at 0x37f0ec610>,
#  <Metabolite 23dhmp_c__Azotobacter at 0x37f856a60>,
#  <Metabolite fum_c__Azotobacter at 0x37f7392b0>,
#  <Metabolite succ_c__Azotobacter at 0x37f4d4850>,
#  <Metabolite actp_c__Azotobacter at 0x37f8f6af0>,
#  <Metabolite hxan_e__Azotobacter at 0x3803189a0>,
#  <Metabolite lac__L_e__Azotobacter at 0x37f8f24c0>,
#  <Metabolite no3_e__Azotobacter at 0x3800464c0>,
#  <Metabolite orn_e__Azotobacter at 0x37f8cdfd0>,
#  <Metabolite pyr_e__Azotobacter at 0x3802c12b0>,
#  <Metabolite succ_e__Azotobacter at 0x3806582b0>,
#  <Metabolite thymd_e__Azotobacter at 0x3806d84c0>,
#  <Metabolite ckdo_c__Azotobacter at 0x3806d8730>,
#  <Metabolite cmp_c__Azotobacter at 0x3806d8760>,
#  <Metabolite kdolipid4_c__Azotobacter at 0x3806d8790>,
#  <Metabolite lipidA_c__Azotobacter at 0x3806d87c0>,
#  <Metabolite udcpdp_c__Azotobacter at 0x3806d88e0>,
#  <Metabolite lipidX_c__Azotobacter at 0x3806d89a0>,
#  <Metabolite u23ga_c__Azotobacter at 0x3806d8820>,
#  <Metabolite lipidAds_c__Azotobacter at 0x3806d8cd0>,
#  <Metabolite udp_c__Azotobacter at 0x3806d8af0>,
#  <Metabolite btn_e__Azotobacter at 0x3806fb8b0>,
#  <Metabolite spmd_e__Azotobacter at 0x3807067f0>,
#  <Metabolite thym_e__Azotobacter at 0x38072ffd0>,
#  ...]

# %% [markdown]
# and importantly the `medium`

# %%
community.medium
# Out:
# {'EX_hco3_m': 1.99,
#  'EX_mn2_m': 999999.0,
#  'EX_mg2_m': 999999.0,
#  'EX_ca2_m': 999999.0,
#  'EX_nh4_m': 5.0,
#  'EX_fe2_m': 0.05,
#  'EX_cu2_m': 999999.0,
#  'EX_k_m': 999999.0,
#  'EX_h2o_m': 999999.0,
#  'EX_o2_m': 999999.0,
#  'EX_co2_m': 1.99,
#  'EX_leu__L_m': 1000.0,
#  'EX_cobalt2_m': 999999.0,
#  'EX_no3_m': 1.76,
#  'EX_zn2_m': 999999.0,
#  'EX_fe3_m': 0.05,
#  'EX_so4_m': 999999.0,
#  'EX_mobd_m': 999999.0,
#  'EX_ni2_m': 999999.0,
#  'EX_na1_m': 999999.0,
#  'EX_h_m': 999999.0,
#  'EX_photon410_m': 1000.0,
#  'EX_photon430_m': 1000.0,
#  'EX_photon450_m': 1000.0,
#  'EX_photon470_m': 1000.0,
#  'EX_photon490_m': 1000.0,
#  'EX_photon510_m': 1000.0,
#  'EX_photon530_m': 1000.0,
#  'EX_photon550_m': 1000.0,
#  'EX_photon570_m': 1000.0,
#  'EX_photon590_m': 1000.0,
#  'EX_photon610_m': 1000.0,
#  'EX_photon630_m': 1000.0,
#  'EX_photon650_m': 1000.0,
#  'EX_photon670_m': 1000.0,
#  'EX_photon690_m': 1000.0,
#  'EX_pi_m': 999999.0,
#  'EX_cl_m': 999999.0,
#  'EX_glc__D_m': 5.0,
#  'EX_sel_m': 999999.0,
#  'EX_tungs_m': 999999.0,
#  'EX_slnt_m': 999999.0}

# %% [markdown]
# This behavior mimics the medium in `cobrapy`, but combines both models mediums into 1

# %% [markdown]
# ### Running Optimization
#
# Now that we have the model loaded, we can run standard `FBA` methods using `optimize()`. Default optimize does not return any fluxes from the model, so we can set the `fluxes=True` when calling the method to return them.

# %%
result = community.optimize(fluxes=True)
result
# Out:
# <CommunitySolution 0.844 at 0x34fe31430>

# %% [markdown]
# We can see that both organisms have a non-zero growth rate and that the community growth is also non-zero. Let's check the fluxes.

# %%
result.fluxes.T.loc['EX_nh4_e']
# Out:
# compartment
# Azotobacter       0.0
# Synechococcus   -10.0
# medium            NaN
# Name: EX_nh4_e, dtype: float64

# %% [markdown]
# #### Changing parts of the medium to test it's effect on growth
#
# Now that we can successfully optimize the community model, we can begin altering the models medium and seeing how it changes the (community) growth rate.

# %% [markdown]
# First, let's make a copy of the original medium so that we can restore it after making changes.

# %%
medium_bkp = community.medium

# %% [markdown]
# Now we can make changes to the medium. The following cell is meant to be re-run with making changes. It will first restore the medium to the original and them set

# %%
# Restore medium to original
community.medium = medium_bkp

# Set variable to become new medium
medium_to_change = community.medium

#Add or subtract reactions
medium_to_change["EX_nh4_m"] = 0
#medium_to_change["EX_sucr_m"] = 0
#medium_to_change["EX_leu__L_m"] = 1

# Set the new medium as the model's medium
community.medium = medium_to_change
community.medium
# Out:
# {'EX_hco3_m': 1.99,
#  'EX_mn2_m': 999999.0,
#  'EX_mg2_m': 999999.0,
#  'EX_ca2_m': 999999.0,
#  'EX_fe2_m': 0.05,
#  'EX_cu2_m': 999999.0,
#  'EX_k_m': 999999.0,
#  'EX_h2o_m': 999999.0,
#  'EX_o2_m': 999999.0,
#  'EX_co2_m': 1.99,
#  'EX_leu__L_m': 1000.0,
#  'EX_cobalt2_m': 999999.0,
#  'EX_no3_m': 1.76,
#  'EX_zn2_m': 999999.0,
#  'EX_fe3_m': 0.05,
#  'EX_so4_m': 999999.0,
#  'EX_mobd_m': 999999.0,
#  'EX_ni2_m': 999999.0,
#  'EX_na1_m': 999999.0,
#  'EX_h_m': 999999.0,
#  'EX_photon410_m': 1000.0,
#  'EX_photon430_m': 1000.0,
#  'EX_photon450_m': 1000.0,
#  'EX_photon470_m': 1000.0,
#  'EX_photon490_m': 1000.0,
#  'EX_photon510_m': 1000.0,
#  'EX_photon530_m': 1000.0,
#  'EX_photon550_m': 1000.0,
#  'EX_photon570_m': 1000.0,
#  'EX_photon590_m': 1000.0,
#  'EX_photon610_m': 1000.0,
#  'EX_photon630_m': 1000.0,
#  'EX_photon650_m': 1000.0,
#  'EX_photon670_m': 1000.0,
#  'EX_photon690_m': 1000.0,
#  'EX_pi_m': 999999.0,
#  'EX_cl_m': 999999.0,
#  'EX_glc__D_m': 5.0,
#  'EX_sel_m': 999999.0,
#  'EX_tungs_m': 999999.0,
#  'EX_slnt_m': 999999.0}

# %% [markdown]
# Now that the medium is changed, we can rerun the model optimization.

# %%
result_altered_medium = community.optimize(fluxes=True)

# %%
result_altered_medium.fluxes.T.loc['EX_nh4_e']
# Out:
# compartment
# Azotobacter      1.07232
# Synechococcus   -1.07232
# medium               NaN
# Name: EX_nh4_e, dtype: float64

# %% [markdown]
# ## Running the Models with MICOM Grow
#
# An alternative to running standard community optimization with `optimize()`, we can also use a `micom.workflows` method called `grow()`. This simulates growth of the organism while also simulating potential tradeoffs (between prioritizing community vs. individual growth). This method does not require our previously constructed `community` object, but rather the `manifest` we added earlier.
#
# A key difference here though, is that we need to create a `DataFrame` detailing the reaction, flux, and metabolite as the medium provided to the method.

# %% [markdown]
# ### Building the Medium

# %%
# Restore medium to original
community.medium = medium_bkp

# Set variable to become new medium
grow_medium_to_change = community.medium

#Add or subtract reactions
#grow_medium_to_change["EX_glc__D_m"] = 0
#grow_medium_to_change["EX_sucr_m"] = 1
grow_medium_to_change["EX_nh4_m"] = 0

# %%
grow_medium = pd.Series(grow_medium_to_change).to_frame('flux').reset_index()
grow_medium = grow_medium.rename(columns={'index':'reaction'})
grow_medium
# Out:
#           reaction       flux
# 0        EX_hco3_m       1.99
# 1         EX_mn2_m  999999.00
# 2         EX_mg2_m  999999.00
# 3         EX_ca2_m  999999.00
# 4         EX_nh4_m       0.00
# 5         EX_fe2_m       0.05
# 6         EX_cu2_m  999999.00
# 7           EX_k_m  999999.00
# 8         EX_h2o_m  999999.00
# 9          EX_o2_m  999999.00
# 10        EX_co2_m       1.99
# 11     EX_leu__L_m    1000.00
# 12    EX_cobalt2_m  999999.00
# 13        EX_no3_m       1.76
# 14        EX_zn2_m  999999.00
# 15        EX_fe3_m       0.05
# 16        EX_so4_m  999999.00
# 17       EX_mobd_m  999999.00
# 18        EX_ni2_m  999999.00
# 19        EX_na1_m  999999.00
# 20          EX_h_m  999999.00
# 21  EX_photon410_m    1000.00
# 22  EX_photon430_m    1000.00
# 23  EX_photon450_m    1000.00
# 24  EX_photon470_m    1000.00
# 25  EX_photon490_m    1000.00
# 26  EX_photon510_m    1000.00
# 27  EX_photon530_m    1000.00
# 28  EX_photon550_m    1000.00
# 29  EX_photon570_m    1000.00
# 30  EX_photon590_m    1000.00
# 31  EX_photon610_m    1000.00
# 32  EX_photon630_m    1000.00
# 33  EX_photon650_m    1000.00
# 34  EX_photon670_m    1000.00
# 35  EX_photon690_m    1000.00
# 36         EX_pi_m  999999.00
# 37         EX_cl_m  999999.00
# 38     EX_glc__D_m       5.00
# 39        EX_sel_m  999999.00
# 40      EX_tungs_m  999999.00
# 41       EX_slnt_m  999999.00

# %%
result_grow = grow(manifest, model_folder="models_av_se", medium=grow_medium, tradeoff=0.01, threads=2,presolve=True)
# Out:
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/1f/ksln774x1hd1pzfgsjgpxt7r0000gn/T/tmp8nq38lme.lp
# Reading time = 0.03 seconds
# : 3116 rows, 7325 columns, 28585 nonzeros
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
result_grow.exchanges
# Out:
#              taxon sample_id  tolerance        reaction      flux  abundance  \
# 12     Azotobacter       One   0.000001         EX_h2_e  0.078976        0.5
# 14     Azotobacter       One   0.000001        EX_ade_e  0.000002        0.5
# 21     Azotobacter       One   0.000001        EX_zn2_e -0.000003        0.5
# 28     Azotobacter       One   0.000001        EX_nh4_e  0.207363        0.5
# 63     Azotobacter       One   0.000001         EX_o2_e -1.197536        0.5
# 73     Azotobacter       One   0.000001        EX_no3_e -0.286904        0.5
# 99     Azotobacter       One   0.000001         EX_ac_e  1.787752        0.5
# 100    Azotobacter       One   0.000001        EX_ni2_e -0.000002        0.5
# 121    Azotobacter       One   0.000001        EX_h2o_e  1.657742        0.5
# 124    Azotobacter       One   0.000001          EX_h_e  1.283990        0.5
# 156    Azotobacter       One   0.000001        EX_fe2_e -0.000063        0.5
# 170    Azotobacter       One   0.000001     EX_glc__D_e -0.950724        0.5
# 177    Azotobacter       One   0.000001         EX_cl_e -0.000040        0.5
# 212    Azotobacter       One   0.000001        EX_mn2_e -0.000005        0.5
# 214    Azotobacter       One   0.000001         EX_pi_e -0.007337        0.5
# 216    Azotobacter       One   0.000001        EX_co2_e  1.825279        0.5
# 220    Azotobacter       One   0.000001        EX_so4_e -0.001231        0.5
# 231    Azotobacter       One   0.000001        EX_ca2_e -0.000040        0.5
# 255    Azotobacter       One   0.000001        EX_mg2_e -0.000066        0.5
# 266    Azotobacter       One   0.000001        EX_cu2_e -0.000005        0.5
# 319    Azotobacter       One   0.000001          EX_k_e -0.001485        0.5
# 322    Azotobacter       One   0.000001        EX_fe3_e -0.000059        0.5
# 337         medium       One   0.000001         EX_ac_m  0.893876        NaN
# 350         medium       One   0.000001        EX_cu2_m -0.000003        NaN
# 372         medium       One   0.000001        EX_ni2_m -0.000001        NaN
# 386         medium       One   0.000001         EX_pi_m -0.009541        NaN
# 416         medium       One   0.000001        EX_so4_m -0.002759        NaN
# 432         medium       One   0.000001        EX_mn2_m -0.000003        NaN
# 443         medium       One   0.000001        EX_co2_m  0.404394        NaN
# 455         medium       One   0.000001        EX_fe3_m -0.000052        NaN
# 463         medium       One   0.000001  EX_photon650_m -2.172682        NaN
# 486         medium       One   0.000001       EX_hco3_m -0.046930        NaN
# 497         medium       One   0.000001     EX_leu__L_m -0.007243        NaN
# 498         medium       One   0.000001         EX_cl_m -0.000020        NaN
# 521         medium       One   0.000001         EX_h2_m  0.039488        NaN
# 540         medium       One   0.000001  EX_photon430_m -0.000154        NaN
# 546         medium       One   0.000001        EX_ca2_m -0.000020        NaN
# 571         medium       One   0.000001        EX_mg2_m -0.000187        NaN
# 580         medium       One   0.000001        EX_zn2_m -0.000001        NaN
# 590         medium       One   0.000001        EX_h2o_m  0.607165        NaN
# 608         medium       One   0.000001     EX_glc__D_m -0.475362        NaN
# 620         medium       One   0.000001          EX_k_m -0.000742        NaN
# 638         medium       One   0.000001        EX_fe2_m -0.000031        NaN
# 645         medium       One   0.000001        EX_no3_m -0.143452        NaN
# 646         medium       One   0.000001  EX_photon690_m -4.101377        NaN
# 662         medium       One   0.000001          EX_h_m  0.691676        NaN
# 667  Synechococcus       One   0.000001     EX_leu__L_e -0.014485        0.5
# 670  Synechococcus       One   0.000001        EX_nh4_e -0.207363        0.5
# 672  Synechococcus       One   0.000001         EX_o2_e  1.197536        0.5
# 680  Synechococcus       One   0.000001        EX_h2o_e -0.443412        0.5
# 681  Synechococcus       One   0.000001          EX_h_e  0.099362        0.5
# 693  Synechococcus       One   0.000001         EX_pi_e -0.011746        0.5
# 694  Synechococcus       One   0.000001        EX_co2_e -1.016491        0.5
# 695  Synechococcus       One   0.000001        EX_so4_e -0.004287        0.5
# 699  Synechococcus       One   0.000001        EX_mg2_e -0.000309        0.5
# 700  Synechococcus       One   0.000001  EX_photon690_e -8.202755        0.5
# 701  Synechococcus       One   0.000001       EX_hco3_e -0.093860        0.5
# 706  Synechococcus       One   0.000001  EX_photon650_e -4.345364        0.5
# 708  Synechococcus       One   0.000001        EX_fe3_e -0.000044        0.5
# 709  Synechococcus       One   0.000001  EX_photon430_e -0.000309        0.5
#
#       metabolite direction
# 12          h2_e    export
# 14         ade_e    export
# 21         zn2_e    import
# 28         nh4_e    export
# 63          o2_e    import
# 73         no3_e    import
# 99          ac_e    export
# 100        ni2_e    import
# 121        h2o_e    export
# 124          h_e    export
# 156        fe2_e    import
# 170     glc__D_e    import
# 177         cl_e    import
# 212        mn2_e    import
# 214         pi_e    import
# 216        co2_e    export
# 220        so4_e    import
# 231        ca2_e    import
# 255        mg2_e    import
# 266        cu2_e    import
# 319          k_e    import
# 322        fe3_e    import
# 337         ac_m    export
# 350        cu2_m    import
# 372        ni2_m    import
# 386         pi_m    import
# 416        so4_m    import
# 432        mn2_m    import
# 443        co2_m    export
# 455        fe3_m    import
# 463  photon650_m    import
# 486       hco3_m    import
# 497     leu__L_m    import
# 498         cl_m    import
# 521         h2_m    export
# 540  photon430_m    import
# 546        ca2_m    import
# 571        mg2_m    import
# 580        zn2_m    import
# 590        h2o_m    export
# 608     glc__D_m    import
# 620          k_m    import
# 638        fe2_m    import
# 645        no3_m    import
# 646  photon690_m    import
# 662          h_m    export
# 667     leu__L_e    import
# 670        nh4_e    import
# 672         o2_e    export
# 680        h2o_e    import
# 681          h_e    export
# 693         pi_e    import
# 694        co2_e    import
# 695        so4_e    import
# 699        mg2_e    import
# 700  photon690_e    import
# 701       hco3_e    import
# 706  photon650_e    import
# 708        fe3_e    import
# 709  photon430_e    import

# %%
result_grow.exchanges.to_csv('av_se_out.csv')
